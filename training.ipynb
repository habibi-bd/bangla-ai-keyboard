# %%
# check for further details
# https://www.kaggle.com/code/yahabibitoday/bangla-keyboard

# %%
import random
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 


import torch 
import torch.nn as nn 
from torch.utils.data import DataLoader, Dataset

# %%
random.seed(42)
pytorch_seed = torch.manual_seed(seed=42)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
df = pd.read_csv(filepath_or_buffer="pure_bangla.txt",
                 sep="\t",names=["data"],header=None)
df
# Out:
#                                                    data
# 0     কর্পোরেশনের দোষ তো আছে । কিন্তু আমরা যে সুযোগ ...
# 1     নিজের অজান্তেই চায়ে চুমুক দিলাম । দিয়ে মনে হলো...
# 2     পাঞ্জাবির পকেট থেকে অদ্ভুত একটা মোবাইল ফোন বের...
# 3     সে সওদাগর হয়ে বিরাট কারবার চালাতে লাগল । প্রা...
# 4     একদিন ছেলেকে এই কথা জিজ্ঞেস করতেই ছেলেটি হতভম্...
# ...                                                 ...
# 2203  নিজের অজান্তেই চায়ে চুমুক দিলাম । দিয়ে মনে হলো...
# 2204  পাঞ্জাবির পকেট থেকে অদ্ভুত একটা মোবাইল ফোন বের...
# 2205  সে সওদাগর হয়ে বিরাট কারবার চালাতে লাগল । প্রা...
# 2206  একদিন ছেলেকে এই কথা জিজ্ঞেস করতেই ছেলেটি হতভম্...
# 2207  ইয়োরোপ ঘুরে বেড়ানোর জন্য এর চাইতে ভালো স্কলারশ...
#
# [2208 rows x 1 columns]

# %%
df["data"][0].split(" ")
# Out:
# ['কর্পোরেশনের',
#  'দোষ',
#  'তো',
#  'আছে',
#  '।',
#  'কিন্তু',
#  'আমরা',
#  'যে',
#  'সুযোগ',
#  'বুঝে',
#  'হাজার',
#  'হাজার',
#  'কোটি',
#  'টাকার',
#  'ট্যাক্স',
#  'ফাকি',
#  'দিয়ে',
#  'আসছি',
#  'সেটাও',
#  'আমরা',
#  'জানি',
#  '।',
#  'এই',
#  'ভয়ে',
#  'সবাই',
#  'স্যু',
#  'করার',
#  'সাহস',
#  'পাবেনা',
#  '।',
#  'কারণ',
#  'উলটা',
#  'স্যু',
#  'সে',
#  'নিজে',
#  'খেয়ে',
#  'যাবে',
#  '।',
#  'আপনি',
#  'স্যু',
#  'করে',
#  'দৃষ্টান্ত',
#  'শুরু',
#  'করে',
#  'দিলেই',
#  'পারেন',
#  '।',
#  'অন্যরাও',
#  'ধীরে',
#  'ধীরে',
#  'উৎসাহিত',
#  'হবে',
#  '।',
#  'পরিবর্তন',
#  'আসবে',
#  '।',
#  'আমাদের',
#  'সবার',
#  'মনেই',
#  'বিদেশে',
#  'পড়তে',
#  'যাওয়ার',
#  'সুপ্ত',
#  'কিন্তু',
#  'তীব্র',
#  'আকাঙ্ক্ষা',
#  'কাজ',
#  'করে',
#  '।',
#  'বিদেশে',
#  'পড়ার',
#  'ক্ষেত্রে',
#  'খরচের',
#  'ব্যাপারটা',
#  'মাথায়',
#  'আসে',
#  'বলেই',
#  'আমরা',
#  'অনেকেই',
#  'চাই',
#  'বৃত্তি',
#  'বা',
#  'স্কলারশিপ',
#  'এর',
#  'ব্যাপারে',
#  'খোঁজ',
#  'নিতে',
#  '।',
#  'পুরো',
#  'প্রক্রিয়াটি',
#  'অনেক',
#  'বিশদ',
#  'হওয়ায়',
#  'আমার',
#  'ক্ষুদ্র',
#  'অভিজ্ঞতা',
#  'থেকে',
#  'আমি',
#  'চেষ্টা',
#  'করবো',
#  'আমার',
#  'শিক্ষার্থীদের',
#  'কিছুটা',
#  'জানানোর',
#  '।',
#  'আমার',
#  'লেখাটা',
#  'টি',
#  'পর্বে',
#  'থাকবে',
#  '।',
#  'আজ',
#  'প্রথম',
#  'পর্ব',
#  '।',
#  'আজকে',
#  'আমি',
#  'আলোচনা',
#  'করবো',
#  'বাংলাদেশি',
#  'শিক্ষার্থীদের',
#  'জন্য',
#  'বিদেশে',
#  'পড়তে',
#  'যাওয়ার',
#  'স্কলারশিপ',
#  'নিয়ে',
#  '।',
#  'পরবর্তীতে',
#  'বিভিন্ন',
#  'দেশে',
#  'এপ্লাই',
#  'করার',
#  'প্রক্রিয়া',
#  'ক্রেডিট',
#  'ট্রান্সফার',
#  'বিশ্ববিদ্যালয়ের',
#  'ইন',
#  'হাউস',
#  'স্কলারশিপ',
#  'ইত্যাদি',
#  'বিষয়ে',
#  'আলোচনা',
#  'করবো',
#  '।',
#  'যুক্তরাজ্যে',
#  'পড়তে',
#  'যাওয়ার',
#  'জন্য',
#  'ব্রিটিশ',
#  'সরকারের',
#  'বৃত্তি',
#  'এটি',
#  '।',
#  'অত্যন্ত',
#  'সম্মানজনক',
#  'এবং',
#  'সেইসাথে',
#  'খুবই',
#  'প্রতিযোগিতামূলক',
#  '।',
#  'সাধারণত',
#  'যারা',
#  'শিক্ষকতা',
#  'পেশায়',
#  'নিয়োজিত',
#  'থাকেন',
#  'তারা',
#  'এটা',
#  'পেয়ে',
#  'থাকেন',
#  'তবে',
#  'শিক্ষকই',
#  'হতে',
#  'হবে',
#  'এমন',
#  'কোনো',
#  'বাধ্যবাধকতা',
#  'নেই',
#  '।',
#  'আপনার',
#  'বয়স',
#  'কম',
#  'হলে',
#  'এবং',
#  'আপনার',
#  'ব্যাচেলর',
#  'ডিগ্রিতে',
#  'নম্বর',
#  'থাকলেই',
#  'আপনি',
#  'এই',
#  'স্কলারশিপের',
#  'জন্য',
#  'এপ্লাই',
#  'করতে',
#  'পারবেন',
#  '।',
#  'এক্ষেত্রে',
#  'যেটা',
#  'লাগবে',
#  'সেটা',
#  'হলো',
#  'যুক্তরাজ্যের',
#  'কোনো',
#  'একটি',
#  'বিশ্ববিদ্যালয়ে',
#  'ভর্তির',
#  'আনকন্ডিশনাল',
#  'অফার',
#  'লেটার',
#  '।',
#  'গুগল',
#  'করলেই',
#  'লিস্ট',
#  'পাবেন',
#  'ব্রিটেনের',
#  'কোন',
#  'কোন',
#  'বিশ্ববিদ্যালয়',
#  'কমনওয়েলথের',
#  'আওতায়',
#  'আছে',
#  '।',
#  'তারমানে',
#  'আপনার',
#  'আগে',
#  'বিশ্ববিদ্যালয়ে',
#  'ওদের',
#  'নিজস্ব',
#  'সিস্টেমে',
#  'এপ্লাই',
#  'করতে',
#  'হবে',
#  'আর',
#  'অফার',
#  'লেটার',
#  'পেলেই',
#  'আপনি',
#  'কমনওয়েলথের',
#  'জন্য',
#  'এপ্লাই',
#  'করতে',
#  'পারবেন',
#  '।',
#  'দুটোর',
#  'ক্ষেত্রেই',
#  'এপ্লিকেশন',
#  'প্রোসেস',
#  'ভিন্ন',
#  '।',
#  'এছাড়া',
#  'স্কলারশিপের',
#  'ক্ষেত্রেও',
#  'আইল্টসের',
#  'স্কোর',
#  'আপনার',
#  'জন্য',
#  'একটা',
#  'ফ্যাক্টর',
#  'হবে',
#  '।',
#  'কমনওয়েলথ',
#  'সাধারণত',
#  'ওপেন',
#  'হয়',
#  'নভেম্বরের',
#  'দিকে',
#  '।',
#  'সময়',
#  'থাকে',
#  '২',
#  'মাসের',
#  'মতো',
#  '।',
#  'এটাও',
#  'কমনওয়েলথের',
#  'মতই',
#  'কিন্তু',
#  'এটার',
#  'ফাণ্ডিং',
#  'অর্ধেক',
#  'যেই',
#  'বিশ্ববিদ্যালয়',
#  'এফিলিয়েটেড',
#  'সেটা',
#  'দিবে',
#  'আর',
#  'বাকি',
#  'অর্ধেক',
#  'দিবে',
#  'কমনওয়েলথ',
#  'স্কলারশিপ',
#  'কমিটি',
#  '।',
#  'বাকিসব',
#  'ক্রাইটেরিয়া',
#  'একই',
#  '।',
#  'তবে',
#  'বিশ্ববিদ্যালয়ের',
#  'একটা',
#  'তালিকা',
#  'থাকে',
#  'যে',
#  'কোন',
#  'কোন',
#  'বিশ্ববিদ্যালয়',
#  'এই',
#  'শেয়ারড',
#  'প্রোগ্রামের',
#  'আওতায়',
#  '।',
#  'যুক্তরাজ্যে',
#  'পড়তে',
#  'যাওয়ার',
#  'জন্য',
#  'ব্রিটিশ',
#  'সরকারের',
#  'বৃত্তি',
#  '।',
#  'সাধারণত',
#  'এনজিও',
#  'কর্মী',
#  'সরকারী',
#  'চাকুরে',
#  'বাংলাদেশ',
#  'ব্যাংকের',
#  'কর্মকর্তা',
#  'উদ্যোক্তা',
#  'এদের',
#  'জন্য',
#  'এই',
#  'বৃত্তি',
#  '।',
#  'আপনার',
#  'চাকরি',
#  'যদি',
#  'দুই',
#  'বছর',
#  'হয়',
#  'তাহলে',
#  'এটার',
#  'জন্য',
#  'এপ্লাই',
#  'করতে',
#  'পারবেন',
#  '।',
#  'ক্রাইটেরিয়া',
#  'একই',
#  'রকম',
#  '।',
#  'আইল্টসে',
#  'ভালো',
#  'স্কোর',
#  'আর',
#  'ইউকের',
#  'বিশ্ববিদ্যালয়',
#  'থেকে',
#  'আনকন্ডিশনাল',
#  'অফার',
#  'লেটার',
#  'লাগবে',
#  '।',
#  'মার্কিন',
#  'সরকারের',
#  'বৃত্তি',
#  '।',
#  'দারুণ',
#  'প্রেস্টিজিয়াস',
#  'এবং',
#  'আর্থিক',
#  'দিক',
#  'থেকেও',
#  'বেশ',
#  'লাভজনক',
#  '।',
#  'মূল',
#  'বৃত্তিটির',
#  'নাম',
#  'হলো',
#  'ফুলব্রাইট',
#  'ফরেন',
#  'স্টুডেন্ট',
#  'প্রোগ্রাম',
#  '।',
#  'এটার',
#  'ক্ষেত্রে',
#  'আলাদাভাবে',
#  'কোনো',
#  'বিশ্ববিদ্যালয়ে',
#  'এপ্লাই',
#  'করতে',
#  'হবেনা',
#  '।',
#  'ফুলব্রাইটে',
#  'এপ্লাই',
#  'করলেই',
#  'হবে',
#  '।',
#  'যদি',
#  'আপনি',
#  'বৃত্তির',
#  'জন্য',
#  'মনোনীত',
#  'হোন',
#  'তাহলে',
#  'তারাই',
#  'আপনাকে',
#  'বিশ্ববিদ্যালয়',
#  'নির্ধারণ',
#  'করে',
#  'দিবে',
#  '।',
#  'ইয়োরোপ',
#  'ঘুরে',
#  'বেড়ানোর',
#  'জন্য',
#  'এর',
#  'চাইতে',
#  'ভালো',
#  'স্কলারশিপ',
#  'আর',
#  'হয়না',
#  '।',
#  'বিশেষ',
#  'করে',
#  'সায়েন্স',
#  'এন্ড',
#  'টেকনোলজিতে',
#  'যারা',
#  'পড়ছেন',
#  'তাদের',
#  'জন্য',
#  'এটা',
#  'বেশ',
#  'লিউক্রেটিভ',
#  '।',
#  'সিজিপিএ',
#  'ভালো',
#  'থাকা',
#  'লাগবে',
#  '।',
#  'এই',
#  'স্কলারশিপের',
#  'মজা',
#  'হলো',
#  'ওরা',
#  'আ',
#  'পনাকে',
#  'ইয়োরোপের',
#  'দুটো',
#  'দেশের',
#  'দুই',
#  'বিশ্ববিদ্যালয়ে',
#  'যৌথভাবে',
#  'দুই',
#  'বছরের',
#  'মাস্টার্স',
#  'ডিগ্রি',
#  'করাবে',
#  '।',
#  'বৃত্তির',
#  'পরিমাণ',
#  'বেশ',
#  'ভালো',
#  '।',
#  'কোনো',
#  'চাকরির',
#  'অভিজ্ঞতা',
#  'লাগবেনা',
#  '।',
#  'বিশ্বের',
#  'যেকোনো',
#  'বিশ্ববিদ্যালয়',
#  'থেকে',
#  'আপনি',
#  'আনকন্ডিশনাল',
#  'অফার',
#  'লেটার',
#  'পেলে',
#  'আপনি',
#  'এটায়',
#  'এপ্লাই',
#  'করতে',
#  'পারবেন',
#  '।',
#  'আইল্টস',
#  'দেওয়া',
#  'লাগবে',
#  '।',
#  'বিশ্ববিদ্যালয়',
#  'অফার',
#  'পাওয়ার',
#  'পর',
#  'আলদাভাবে',
#  'এপ্লাই',
#  'করতে',
#  'হবে',
#  '।',
#  'সাধারণত',
#  'জানুয়ারি',
#  'ফেব্রুয়ারিতে',
#  'ওপেন',
#  'হয়ে',
#  'এপ্রিল',
#  'পর্যন্ত',
#  'সময়',
#  'থাকে',
#  '।',
#  'বিশ্বের',
#  'ভালো',
#  'র\u200d্যাংকের',
#  'বিশ্ববিদ্যালয়ে',
#  'ভর্তি',
#  'হয়ে',
#  'অফার',
#  'লেটার',
#  'নিয়ে',
#  'এই',
#  'স্কলারশিপে',
#  'এপ্লাই',
#  'করতে',
#  'হয়',
#  '।',
#  'সাধারণত',
#  'উন্নয়ন',
#  'বিষয়ক',
#  'পড়ালেখার',
#  'জন্য',
#  'এই',
#  'বৃত্তি',
#  'দেওয়া',
#  'হয়',
#  '।',
#  'দারুণ',
#  'একটা',
#  'সিভি',
#  'লাগবে',
#  '।',
#  'ফরম্যাট',
#  'অনেকেই',
#  'দিয়ে',
#  'দেয়',
#  'যেমন',
#  'ইরেসমাসে',
#  'আপনাকে',
#  'সিভি',
#  'ফরম্যাট',
#  'ওরাই',
#  'দিয়ে',
#  'দিবে',
#  '।',
#  'বাকিগুলোর',
#  'ক্ষেত্রে',
#  'সিভি',
#  'হবে',
#  'সিম্পল',
#  'কিন্তু',
#  'বেশ',
#  'ঝকঝকে',
#  '।',
#  'মিথ্যা',
#  'কোনো',
#  'ইনফরমেশন',
#  'দেওয়া',
#  'যাবেনা',
#  '।',
#  'আপনার',
#  'বিশ্ববিদ্যালয়ের',
#  'থিসিস',
#  'সুপারভাইজর',
#  'বা',
#  'শিক্ষক',
#  'বা',
#  'আপনার',
#  'কর্মক্ষেত্রের',
#  'বস',
#  'থেকে',
#  'আপনার',
#  'দুটো',
#  'রেফারেন্স',
#  'লেটার',
#  'লাগবে',
#  '।',
#  'এ',
#  'ক্ষেত্রে',
#  'যে',
#  'আপনাকে',
#  'রেফারেন্স',
#  'দিবে',
#  'অর্থাৎ',
#  'রেফারির',
#  'যোগ্যতাও',
#  'সেই',
#  'লেভেলের',
#  'হতে',
#  'হবে',
#  '।',
#  'সে',
#  'আপনার',
#  'যোগ্যতা',
#  'দুর্বলতা',
#  'এবং',
#  'পোটেনশিয়াল',
#  'সম্পর্কে',
#  'জানবে',
#  '।',
#  'কাজেই',
#  'রেফারি',
#  'নির্বাচনের',
#  'ক্ষেত্রে',
#  'সতর্ক',
#  'হোন',
#  'এবং',
#  'আগে',
#  'থেকেই',
#  'সুসম্পর্ক',
#  'বজায়',
#  'রাখুন',
#  '।',
#  'নিজের',
#  'যোগ্যতা',
#  'দিয়ে',
#  'সুসম্পর্ক',
#  'বজায়',
#  'রাখবেন',
#  '।',
#  'মাথায়',
#  'রাখবেন',
#  'আপনাকে',
#  'কেউ',
#  'কিছু',
#  'মুখে',
#  'তুলে',
#  'খাওয়াবে',
#  'না',
#  '।',
#  'কষ্ট',
#  'করতে',
#  'হবে',
#  '।',
#  'নিজের',
#  'সাথে',
#  'প্রতিযোগিতা',
#  'করতে',
#  'হবে',
#  '।',
#  'জেলা',
#  'প্রশাসনের',
#  'একজন',
#  'এক্সিকিউটিভ',
#  'ম্যাজিস্ট্রেটকে',
#  'এই',
#  'দায়িত্ব',
#  'দেওয়া',
#  'হয়',
#  '।',
#  'এনডিসির',
#  'কাজ',
#  'হলো',
#  'মূলত',
#  'জেলা',
#  'প্রশাসন',
#  'এবং',
#  'জেলা',
#  'সংশ্লিষ্ট',
#  'সকল',
#  'সরকারি',
#  'বিষয়ে',
#  'লজিস্টিকস',
#  'সাপোর্ট',
#  'দেওয়া',
#  '।',
#  'যেমন',
#  'জেলায়',
#  'কোনো',
#  'ভিআইপি',
#  'আসলে',
#  'যথাযোগ্যভাবে',
#  'তার',
#  'আবাসন',
#  'ও',
#  'পরিবহন',
#  'নিশ্চিত',
#  'করা',
#  '।',
#  'তার',
#  'সফরসঙ্গীদের',
#  'আবাসন',
#  'আহার',
#  'ইত্যাদি',
#  'নিশ্চিত',
#  'করা',
#  'এবং',
#  'জেলার',
#  'পরিবহন',
#  'পুলের',
#  'গাড়ি',
#  'সার্কিট',
#  'হাউজ',
#  'ব্যবস্থাপনা',
#  'শ্রদ্ধেয়',
#  'ডিসি',
#  'স্যারের',
#  'বাংলোর',
#  'তদারকি',
#  'অফিসের',
#  'কার',
#  'কী',
#  'লাগবে',
#  'এক',
#  'কথায়',
#  'সবকিছু',
#  'দেখভাল',
#  'করতে',
#  'হয়',
#  'এই',
#  'এনডিসির',
#  '।',
#  'এনডিসির',
#  'যেই',
#  'অফিশিয়াল',
#  'ফোন',
#  'আছে',
#  'সেটা',
#  'কখনো',
#  'বন্ধ',
#  'হয়না',
#  '।',
#  'রোজ',
#  'কেয়ামতের',
#  'দিনেও',
#  'যদি',
#  'কেউ',
#  'ফোন',
#  'করে',
#  'বলে',
#  '',
#  'স্যার',
#  'গাড়ি',
#  'লাগবে',
#  '।',
#  'থাকা',
#  'লাগবে',
#  'নরসিংদীতে',
#  '।',
#  'স্যার',
#  'এই',
#  'সমস্যা',
#  'হয়েছে',
#  '।',
#  'সেটাও',
#  'এনডিসির',
#  'যেভাবেই',
#  'হোক',
#  'ম্যানেজ',
#  'করা',
#  'লাগবে',
#  '।',
#  'এর',
#  'পাশাপাশি',
#  'দাপ্তরিক',
#  'কাজ',
#  'এবং',
#  'বিচারিক',
#  'কাজ',
#  'তো',
#  'আছেই',
#  '।',
#  'আমি',
#  'তখনো',
#  'বুঝিনি',
#  'কী',
#  'এক',
#  'কর্মযজ্ঞ',
#  'আমার',
#  'জন্য',
#  'অপেক্ষা',
#  'করছিলো।',
#  'আমি',
#  'মাননীয়',
#  'প্রধানমন্ত্রীর',
#  'কার্যালয়ের',
#  'এটুআই',
#  'থেকে',
#  'মেইল',
#  'ফোন',
#  'কল',
#  'পেতে',
#  'থাকলাম',
#  '।',
#  'সময়',
#  'গড়ায়',
#  'আর',
#  'মেইল',
#  'ফোন',
#  'কলের',
#  'গতি',
#  'বাড়ে',
#  '।',
#  'তাদের',
#  'কাজ',
#  'ছিলো',
#  'নরসিংদীর',
#  'পুরো',
#  'জেলার',
#  'সিক্যিউরিটি',
#  'এনশিউর',
#  'করা',
#  '।',
#  'তাদের',
#  'আবাসন',
#  'গাড়িসহ',
#  'সকল',
#  'ধরণের',
#  'রিকোয়ারমেন্টের',
#  'দায়িত্ব',
#  'যথারীতি',
#  'পড়লো',
#  'আমার',
#  'কাঁধে',
#  '।',
#  'নিরাপত্তা',
#  'ইস্যু',
#  'হিসেবে',
#  'তারিখের',
#  'প্রোগ্রামে',
#  'কারা',
#  'কারা',
#  'থাকবে',
#  'তাদের',
#  'সিক্যিউরিটি',
#  'ক্লিয়ারেন্সের',
#  'জন্য',
#  'ডিএসবি',
#  'পাস',
#  'করানো',
#  'থেকে',
#  'শুরু',
#  'করে',
#  'সবকিছু',
#  'খেয়াল',
#  'রাখতে',
#  'হলো',
#  '।',
#  'তারিখ',
#  'আসলো',
#  'সেনাবাহিনীর',
#  'ডগ-স্কোয়াড',
#  '।',
#  'ফোন',
#  'দিয়ে',
#  'বললো',
#  'স্যার',
#  'আমরা',
#  'মেম্বার',
#  'আর',
#  'ছয়টা',
#  'কুকুর',
#  'থাকার',
#  'ব্যবস্থা',
#  'করেন',
#  '।',
#  'আমার',
#  'তখন',
#  'অলরেডি',
#  'সার্কিট',
#  'হাউজ',
#  'ফুল',
#  '।',
#  'ম্যানেজ',
#  'করলাম',
#  '।',
#  'নেভির',
#  'ডাইভার',
#  'দল',
#  'ফোন',
#  'দিয়ে',
#  'বললো',
#  'স্যার',
#  'আমরা',
#  'আসতেছি',
#  '।',
#  'থাকবো',
#  'ম্যানেজ',
#  'করেন',
#  '।',
#  'সেনাবাহিনীর',
#  'সিক্যিউরিটি',
#  'সুইপিং',
#  'টিম',
#  'আসলো',
#  'একটা',
#  'আবাসনের',
#  'ব্যবস্থা',
#  'করলাম',
#  'তাদেরও',
#  '।',
#  'রাণী',
#  'আসার',
#  'কথা',
#  'সড়ক',
#  'পথে',
#  'কিন্তু',
#  'হেলিপ্যাড',
#  'রেডি',
#  'করতে',
#  'হবে',
#  '।',
#  'গণপূর্তের',
#  'নির্বাহী',
#  'প্রকৌশলী',
#  'মহোদয়কে',
#  'বললাম',
#  'স্টেডিয়ামে',
#  'হেলিপ্যাড',
#  'বানান',
#  '।',
#  'বানানো',
#  'হলো',
#  '।',
#  'মোটরকেড',
#  'এবং',
#  'নিরাপত্তার',
#  'দায়িত্বে',
#  'থাকা',
#  'অফিসারের',
#  'জন্য',
#  'প্রচুর',
#  'গাড়ি',
#  'লাগবে',
#  '।',
#  'করলাম',
#  'ম্যানেজ',
#  '।',
#  'এর',
#  'মাঝে',
#  'হঠাত',
#  'বলা',
#  'হলো',
#  'রাণী',
#  'যদি',
#  'লাঞ্চ',
#  'করতে',
#  'চায়',
#  'তাহলে',
#  'মেন্যু',
#  'কী',
#  'হবে',
#  '।',
#  'নেট',
#  'ঘেঁটে',
#  'ডাচদের',
#  'খাবারের',
#  'আইডিয়া',
#  'নিলাম',
#  '।',
#  'আমার',
#  'বউকেও',
#  'বললাম',
#  'হেল্প',
#  'করতে',
#  '।',
#  'যদিও',
#  'ওটা',
#  'পরে',
#  'আর',
#  'প্রয়োজন',
#  'হয়নি',
#  '।',
#  'রাণীর',
#  'জন্য',
#  'মেডিকেল',
#  'টিম',
#  'ফায়ার',
#  'সার্ভিস',
#  'ফুড',
#  'এক্সামিনার',
#  'সহ',
#  'সকল',
#  'কিছু',
#  'রেডি',
#  'রাখলাম',
#  '।',
#  'রাণীকে',
#  'আমাদের',
#  'জেলা',
#  'প্রশাসক',
#  'স্যার',
#  'নরসিংদী',
#  'জেলার',
#  'একটা',
#  'টোকেন',
#  'গিফট',
#  'দিবে',
#  '।',
#  'সেটাও',
#  'রেডি',
#  'করলাম',
#  ...]

# %%
# tokenization
token = [df["data"][i].split(" ") for i in range(0,len(df))]
token[:5]
# Out:
# [['কর্পোরেশনের',
#   'দোষ',
#   'তো',
#   'আছে',
#   '।',
#   'কিন্তু',
#   'আমরা',
#   'যে',
#   'সুযোগ',
#   'বুঝে',
#   'হাজার',
#   'হাজার',
#   'কোটি',
#   'টাকার',
#   'ট্যাক্স',
#   'ফাকি',
#   'দিয়ে',
#   'আসছি',
#   'সেটাও',
#   'আমরা',
#   'জানি',
#   '।',
#   'এই',
#   'ভয়ে',
#   'সবাই',
#   'স্যু',
#   'করার',
#   'সাহস',
#   'পাবেনা',
#   '।',
#   'কারণ',
#   'উলটা',
#   'স্যু',
#   'সে',
#   'নিজে',
#   'খেয়ে',
#   'যাবে',
#   '।',
#   'আপনি',
#   'স্যু',
#   'করে',
#   'দৃষ্টান্ত',
#   'শুরু',
#   'করে',
#   'দিলেই',
#   'পারেন',
#   '।',
#   'অন্যরাও',
#   'ধীরে',
#   'ধীরে',
#   'উৎসাহিত',
#   'হবে',
#   '।',
#   'পরিবর্তন',
#   'আসবে',
#   '।',
#   'আমাদের',
#   'সবার',
#   'মনেই',
#   'বিদেশে',
#   'পড়তে',
#   'যাওয়ার',
#   'সুপ্ত',
#   'কিন্তু',
#   'তীব্র',
#   'আকাঙ্ক্ষা',
#   'কাজ',
#   'করে',
#   '।',
#   'বিদেশে',
#   'পড়ার',
#   'ক্ষেত্রে',
#   'খরচের',
#   'ব্যাপারটা',
#   'মাথায়',
#   'আসে',
#   'বলেই',
#   'আমরা',
#   'অনেকেই',
#   'চাই',
#   'বৃত্তি',
#   'বা',
#   'স্কলারশিপ',
#   'এর',
#   'ব্যাপারে',
#   'খোঁজ',
#   'নিতে',
#   '।',
#   'পুরো',
#   'প্রক্রিয়াটি',
#   'অনেক',
#   'বিশদ',
#   'হওয়ায়',
#   'আমার',
#   'ক্ষুদ্র',
#   'অভিজ্ঞতা',
#   'থেকে',
#   'আমি',
#   'চেষ্টা',
#   'করবো',
#   'আমার',
#   'শিক্ষার্থীদের',
#   'কিছুটা',
#   'জানানোর',
#   '।',
#   'আমার',
#   'লেখাটা',
#   'টি',
#   'পর্বে',
#   'থাকবে',
#   '।',
#   'আজ',
#   'প্রথম',
#   'পর্ব',
#   '।',
#   'আজকে',
#   'আমি',
#   'আলোচনা',
#   'করবো',
#   'বাংলাদেশি',
#   'শিক্ষার্থীদের',
#   'জন্য',
#   'বিদেশে',
#   'পড়তে',
#   'যাওয়ার',
#   'স্কলারশিপ',
#   'নিয়ে',
#   '।',
#   'পরবর্তীতে',
#   'বিভিন্ন',
#   'দেশে',
#   'এপ্লাই',
#   'করার',
#   'প্রক্রিয়া',
#   'ক্রেডিট',
#   'ট্রান্সফার',
#   'বিশ্ববিদ্যালয়ের',
#   'ইন',
#   'হাউস',
#   'স্কলারশিপ',
#   'ইত্যাদি',
#   'বিষয়ে',
#   'আলোচনা',
#   'করবো',
#   '।',
#   'যুক্তরাজ্যে',
#   'পড়তে',
#   'যাওয়ার',
#   'জন্য',
#   'ব্রিটিশ',
#   'সরকারের',
#   'বৃত্তি',
#   'এটি',
#   '।',
#   'অত্যন্ত',
#   'সম্মানজনক',
#   'এবং',
#   'সেইসাথে',
#   'খুবই',
#   'প্রতিযোগিতামূলক',
#   '।',
#   'সাধারণত',
#   'যারা',
#   'শিক্ষকতা',
#   'পেশায়',
#   'নিয়োজিত',
#   'থাকেন',
#   'তারা',
#   'এটা',
#   'পেয়ে',
#   'থাকেন',
#   'তবে',
#   'শিক্ষকই',
#   'হতে',
#   'হবে',
#   'এমন',
#   'কোনো',
#   'বাধ্যবাধকতা',
#   'নেই',
#   '।',
#   'আপনার',
#   'বয়স',
#   'কম',
#   'হলে',
#   'এবং',
#   'আপনার',
#   'ব্যাচেলর',
#   'ডিগ্রিতে',
#   'নম্বর',
#   'থাকলেই',
#   'আপনি',
#   'এই',
#   'স্কলারশিপের',
#   'জন্য',
#   'এপ্লাই',
#   'করতে',
#   'পারবেন',
#   '।',
#   'এক্ষেত্রে',
#   'যেটা',
#   'লাগবে',
#   'সেটা',
#   'হলো',
#   'যুক্তরাজ্যের',
#   'কোনো',
#   'একটি',
#   'বিশ্ববিদ্যালয়ে',
#   'ভর্তির',
#   'আনকন্ডিশনাল',
#   'অফার',
#   'লেটার',
#   '।',
#   'গুগল',
#   'করলেই',
#   'লিস্ট',
#   'পাবেন',
#   'ব্রিটেনের',
#   'কোন',
#   'কোন',
#   'বিশ্ববিদ্যালয়',
#   'কমনওয়েলথের',
#   'আওতায়',
#   'আছে',
#   '।',
#   'তারমানে',
#   'আপনার',
#   'আগে',
#   'বিশ্ববিদ্যালয়ে',
#   'ওদের',
#   'নিজস্ব',
#   'সিস্টেমে',
#   'এপ্লাই',
#   'করতে',
#   'হবে',
#   'আর',
#   'অফার',
#   'লেটার',
#   'পেলেই',
#   'আপনি',
#   'কমনওয়েলথের',
#   'জন্য',
#   'এপ্লাই',
#   'করতে',
#   'পারবেন',
#   '।',
#   'দুটোর',
#   'ক্ষেত্রেই',
#   'এপ্লিকেশন',
#   'প্রোসেস',
#   'ভিন্ন',
#   '।',
#   'এছাড়া',
#   'স্কলারশিপের',
#   'ক্ষেত্রেও',
#   'আইল্টসের',
#   'স্কোর',
#   'আপনার',
#   'জন্য',
#   'একটা',
#   'ফ্যাক্টর',
#   'হবে',
#   '।',
#   'কমনওয়েলথ',
#   'সাধারণত',
#   'ওপেন',
#   'হয়',
#   'নভেম্বরের',
#   'দিকে',
#   '।',
#   'সময়',
#   'থাকে',
#   '২',
#   'মাসের',
#   'মতো',
#   '।',
#   'এটাও',
#   'কমনওয়েলথের',
#   'মতই',
#   'কিন্তু',
#   'এটার',
#   'ফাণ্ডিং',
#   'অর্ধেক',
#   'যেই',
#   'বিশ্ববিদ্যালয়',
#   'এফিলিয়েটেড',
#   'সেটা',
#   'দিবে',
#   'আর',
#   'বাকি',
#   'অর্ধেক',
#   'দিবে',
#   'কমনওয়েলথ',
#   'স্কলারশিপ',
#   'কমিটি',
#   '।',
#   'বাকিসব',
#   'ক্রাইটেরিয়া',
#   'একই',
#   '।',
#   'তবে',
#   'বিশ্ববিদ্যালয়ের',
#   'একটা',
#   'তালিকা',
#   'থাকে',
#   'যে',
#   'কোন',
#   'কোন',
#   'বিশ্ববিদ্যালয়',
#   'এই',
#   'শেয়ারড',
#   'প্রোগ্রামের',
#   'আওতায়',
#   '।',
#   'যুক্তরাজ্যে',
#   'পড়তে',
#   'যাওয়ার',
#   'জন্য',
#   'ব্রিটিশ',
#   'সরকারের',
#   'বৃত্তি',
#   '।',
#   'সাধারণত',
#   'এনজিও',
#   'কর্মী',
#   'সরকারী',
#   'চাকুরে',
#   'বাংলাদেশ',
#   'ব্যাংকের',
#   'কর্মকর্তা',
#   'উদ্যোক্তা',
#   'এদের',
#   'জন্য',
#   'এই',
#   'বৃত্তি',
#   '।',
#   'আপনার',
#   'চাকরি',
#   'যদি',
#   'দুই',
#   'বছর',
#   'হয়',
#   'তাহলে',
#   'এটার',
#   'জন্য',
#   'এপ্লাই',
#   'করতে',
#   'পারবেন',
#   '।',
#   'ক্রাইটেরিয়া',
#   'একই',
#   'রকম',
#   '।',
#   'আইল্টসে',
#   'ভালো',
#   'স্কোর',
#   'আর',
#   'ইউকের',
#   'বিশ্ববিদ্যালয়',
#   'থেকে',
#   'আনকন্ডিশনাল',
#   'অফার',
#   'লেটার',
#   'লাগবে',
#   '।',
#   'মার্কিন',
#   'সরকারের',
#   'বৃত্তি',
#   '।',
#   'দারুণ',
#   'প্রেস্টিজিয়াস',
#   'এবং',
#   'আর্থিক',
#   'দিক',
#   'থেকেও',
#   'বেশ',
#   'লাভজনক',
#   '।',
#   'মূল',
#   'বৃত্তিটির',
#   'নাম',
#   'হলো',
#   'ফুলব্রাইট',
#   'ফরেন',
#   'স্টুডেন্ট',
#   'প্রোগ্রাম',
#   '।',
#   'এটার',
#   'ক্ষেত্রে',
#   'আলাদাভাবে',
#   'কোনো',
#   'বিশ্ববিদ্যালয়ে',
#   'এপ্লাই',
#   'করতে',
#   'হবেনা',
#   '।',
#   'ফুলব্রাইটে',
#   'এপ্লাই',
#   'করলেই',
#   'হবে',
#   '।',
#   'যদি',
#   'আপনি',
#   'বৃত্তির',
#   'জন্য',
#   'মনোনীত',
#   'হোন',
#   'তাহলে',
#   'তারাই',
#   'আপনাকে',
#   'বিশ্ববিদ্যালয়',
#   'নির্ধারণ',
#   'করে',
#   'দিবে',
#   '।',
#   'ইয়োরোপ',
#   'ঘুরে',
#   'বেড়ানোর',
#   'জন্য',
#   'এর',
#   'চাইতে',
#   'ভালো',
#   'স্কলারশিপ',
#   'আর',
#   'হয়না',
#   '।',
#   'বিশেষ',
#   'করে',
#   'সায়েন্স',
#   'এন্ড',
#   'টেকনোলজিতে',
#   'যারা',
#   'পড়ছেন',
#   'তাদের',
#   'জন্য',
#   'এটা',
#   'বেশ',
#   'লিউক্রেটিভ',
#   '।',
#   'সিজিপিএ',
#   'ভালো',
#   'থাকা',
#   'লাগবে',
#   '।',
#   'এই',
#   'স্কলারশিপের',
#   'মজা',
#   'হলো',
#   'ওরা',
#   'আ',
#   'পনাকে',
#   'ইয়োরোপের',
#   'দুটো',
#   'দেশের',
#   'দুই',
#   'বিশ্ববিদ্যালয়ে',
#   'যৌথভাবে',
#   'দুই',
#   'বছরের',
#   'মাস্টার্স',
#   'ডিগ্রি',
#   'করাবে',
#   '।',
#   'বৃত্তির',
#   'পরিমাণ',
#   'বেশ',
#   'ভালো',
#   '।',
#   'কোনো',
#   'চাকরির',
#   'অভিজ্ঞতা',
#   'লাগবেনা',
#   '।',
#   'বিশ্বের',
#   'যেকোনো',
#   'বিশ্ববিদ্যালয়',
#   'থেকে',
#   'আপনি',
#   'আনকন্ডিশনাল',
#   'অফার',
#   'লেটার',
#   'পেলে',
#   'আপনি',
#   'এটায়',
#   'এপ্লাই',
#   'করতে',
#   'পারবেন',
#   '।',
#   'আইল্টস',
#   'দেওয়া',
#   'লাগবে',
#   '।',
#   'বিশ্ববিদ্যালয়',
#   'অফার',
#   'পাওয়ার',
#   'পর',
#   'আলদাভাবে',
#   'এপ্লাই',
#   'করতে',
#   'হবে',
#   '।',
#   'সাধারণত',
#   'জানুয়ারি',
#   'ফেব্রুয়ারিতে',
#   'ওপেন',
#   'হয়ে',
#   'এপ্রিল',
#   'পর্যন্ত',
#   'সময়',
#   'থাকে',
#   '।',
#   'বিশ্বের',
#   'ভালো',
#   'র\u200d্যাংকের',
#   'বিশ্ববিদ্যালয়ে',
#   'ভর্তি',
#   'হয়ে',
#   'অফার',
#   'লেটার',
#   'নিয়ে',
#   'এই',
#   'স্কলারশিপে',
#   'এপ্লাই',
#   'করতে',
#   'হয়',
#   '।',
#   'সাধারণত',
#   'উন্নয়ন',
#   'বিষয়ক',
#   'পড়ালেখার',
#   'জন্য',
#   'এই',
#   'বৃত্তি',
#   'দেওয়া',
#   'হয়',
#   '।',
#   'দারুণ',
#   'একটা',
#   'সিভি',
#   'লাগবে',
#   '।',
#   'ফরম্যাট',
#   'অনেকেই',
#   'দিয়ে',
#   'দেয়',
#   'যেমন',
#   'ইরেসমাসে',
#   'আপনাকে',
#   'সিভি',
#   'ফরম্যাট',
#   'ওরাই',
#   'দিয়ে',
#   'দিবে',
#   '।',
#   'বাকিগুলোর',
#   'ক্ষেত্রে',
#   'সিভি',
#   'হবে',
#   'সিম্পল',
#   'কিন্তু',
#   'বেশ',
#   'ঝকঝকে',
#   '।',
#   'মিথ্যা',
#   'কোনো',
#   'ইনফরমেশন',
#   'দেওয়া',
#   'যাবেনা',
#   '।',
#   'আপনার',
#   'বিশ্ববিদ্যালয়ের',
#   'থিসিস',
#   'সুপারভাইজর',
#   'বা',
#   'শিক্ষক',
#   'বা',
#   'আপনার',
#   'কর্মক্ষেত্রের',
#   'বস',
#   'থেকে',
#   'আপনার',
#   'দুটো',
#   'রেফারেন্স',
#   'লেটার',
#   'লাগবে',
#   '।',
#   'এ',
#   'ক্ষেত্রে',
#   'যে',
#   'আপনাকে',
#   'রেফারেন্স',
#   'দিবে',
#   'অর্থাৎ',
#   'রেফারির',
#   'যোগ্যতাও',
#   'সেই',
#   'লেভেলের',
#   'হতে',
#   'হবে',
#   '।',
#   'সে',
#   'আপনার',
#   'যোগ্যতা',
#   'দুর্বলতা',
#   'এবং',
#   'পোটেনশিয়াল',
#   'সম্পর্কে',
#   'জানবে',
#   '।',
#   'কাজেই',
#   'রেফারি',
#   'নির্বাচনের',
#   'ক্ষেত্রে',
#   'সতর্ক',
#   'হোন',
#   'এবং',
#   'আগে',
#   'থেকেই',
#   'সুসম্পর্ক',
#   'বজায়',
#   'রাখুন',
#   '।',
#   'নিজের',
#   'যোগ্যতা',
#   'দিয়ে',
#   'সুসম্পর্ক',
#   'বজায়',
#   'রাখবেন',
#   '।',
#   'মাথায়',
#   'রাখবেন',
#   'আপনাকে',
#   'কেউ',
#   'কিছু',
#   'মুখে',
#   'তুলে',
#   'খাওয়াবে',
#   'না',
#   '।',
#   'কষ্ট',
#   'করতে',
#   'হবে',
#   '।',
#   'নিজের',
#   'সাথে',
#   'প্রতিযোগিতা',
#   'করতে',
#   'হবে',
#   '।',
#   'জেলা',
#   'প্রশাসনের',
#   'একজন',
#   'এক্সিকিউটিভ',
#   'ম্যাজিস্ট্রেটকে',
#   'এই',
#   'দায়িত্ব',
#   'দেওয়া',
#   'হয়',
#   '।',
#   'এনডিসির',
#   'কাজ',
#   'হলো',
#   'মূলত',
#   'জেলা',
#   'প্রশাসন',
#   'এবং',
#   'জেলা',
#   'সংশ্লিষ্ট',
#   'সকল',
#   'সরকারি',
#   'বিষয়ে',
#   'লজিস্টিকস',
#   'সাপোর্ট',
#   'দেওয়া',
#   '।',
#   'যেমন',
#   'জেলায়',
#   'কোনো',
#   'ভিআইপি',
#   'আসলে',
#   'যথাযোগ্যভাবে',
#   'তার',
#   'আবাসন',
#   'ও',
#   'পরিবহন',
#   'নিশ্চিত',
#   'করা',
#   '।',
#   'তার',
#   'সফরসঙ্গীদের',
#   'আবাসন',
#   'আহার',
#   'ইত্যাদি',
#   'নিশ্চিত',
#   'করা',
#   'এবং',
#   'জেলার',
#   'পরিবহন',
#   'পুলের',
#   'গাড়ি',
#   'সার্কিট',
#   'হাউজ',
#   'ব্যবস্থাপনা',
#   'শ্রদ্ধেয়',
#   'ডিসি',
#   'স্যারের',
#   'বাংলোর',
#   'তদারকি',
#   'অফিসের',
#   'কার',
#   'কী',
#   'লাগবে',
#   'এক',
#   'কথায়',
#   'সবকিছু',
#   'দেখভাল',
#   'করতে',
#   'হয়',
#   'এই',
#   'এনডিসির',
#   '।',
#   'এনডিসির',
#   'যেই',
#   'অফিশিয়াল',
#   'ফোন',
#   'আছে',
#   'সেটা',
#   'কখনো',
#   'বন্ধ',
#   'হয়না',
#   '।',
#   'রোজ',
#   'কেয়ামতের',
#   'দিনেও',
#   'যদি',
#   'কেউ',
#   'ফোন',
#   'করে',
#   'বলে',
#   '',
#   'স্যার',
#   'গাড়ি',
#   'লাগবে',
#   '।',
#   'থাকা',
#   'লাগবে',
#   'নরসিংদীতে',
#   '।',
#   'স্যার',
#   'এই',
#   'সমস্যা',
#   'হয়েছে',
#   '।',
#   'সেটাও',
#   'এনডিসির',
#   'যেভাবেই',
#   'হোক',
#   'ম্যানেজ',
#   'করা',
#   'লাগবে',
#   '।',
#   'এর',
#   'পাশাপাশি',
#   'দাপ্তরিক',
#   'কাজ',
#   'এবং',
#   'বিচারিক',
#   'কাজ',
#   'তো',
#   'আছেই',
#   '।',
#   'আমি',
#   'তখনো',
#   'বুঝিনি',
#   'কী',
#   'এক',
#   'কর্মযজ্ঞ',
#   'আমার',
#   'জন্য',
#   'অপেক্ষা',
#   'করছিলো।',
#   'আমি',
#   'মাননীয়',
#   'প্রধানমন্ত্রীর',
#   'কার্যালয়ের',
#   'এটুআই',
#   'থেকে',
#   'মেইল',
#   'ফোন',
#   'কল',
#   'পেতে',
#   'থাকলাম',
#   '।',
#   'সময়',
#   'গড়ায়',
#   'আর',
#   'মেইল',
#   'ফোন',
#   'কলের',
#   'গতি',
#   'বাড়ে',
#   '।',
#   'তাদের',
#   'কাজ',
#   'ছিলো',
#   'নরসিংদীর',
#   'পুরো',
#   'জেলার',
#   'সিক্যিউরিটি',
#   'এনশিউর',
#   'করা',
#   '।',
#   'তাদের',
#   'আবাসন',
#   'গাড়িসহ',
#   'সকল',
#   'ধরণের',
#   'রিকোয়ারমেন্টের',
#   'দায়িত্ব',
#   'যথারীতি',
#   'পড়লো',
#   'আমার',
#   'কাঁধে',
#   '।',
#   'নিরাপত্তা',
#   'ইস্যু',
#   'হিসেবে',
#   'তারিখের',
#   'প্রোগ্রামে',
#   'কারা',
#   'কারা',
#   'থাকবে',
#   'তাদের',
#   'সিক্যিউরিটি',
#   'ক্লিয়ারেন্সের',
#   'জন্য',
#   'ডিএসবি',
#   'পাস',
#   'করানো',
#   'থেকে',
#   'শুরু',
#   'করে',
#   'সবকিছু',
#   'খেয়াল',
#   'রাখতে',
#   'হলো',
#   '।',
#   'তারিখ',
#   'আসলো',
#   'সেনাবাহিনীর',
#   'ডগ-স্কোয়াড',
#   '।',
#   'ফোন',
#   'দিয়ে',
#   'বললো',
#   'স্যার',
#   'আমরা',
#   'মেম্বার',
#   'আর',
#   'ছয়টা',
#   'কুকুর',
#   'থাকার',
#   'ব্যবস্থা',
#   'করেন',
#   '।',
#   'আমার',
#   'তখন',
#   'অলরেডি',
#   'সার্কিট',
#   'হাউজ',
#   'ফুল',
#   '।',
#   'ম্যানেজ',
#   'করলাম',
#   '।',
#   'নেভির',
#   'ডাইভার',
#   'দল',
#   'ফোন',
#   'দিয়ে',
#   'বললো',
#   'স্যার',
#   'আমরা',
#   'আসতেছি',
#   '।',
#   'থাকবো',
#   'ম্যানেজ',
#   'করেন',
#   '।',
#   'সেনাবাহিনীর',
#   'সিক্যিউরিটি',
#   'সুইপিং',
#   'টিম',
#   'আসলো',
#   'একটা',
#   'আবাসনের',
#   'ব্যবস্থা',
#   'করলাম',
#   'তাদেরও',
#   '।',
#   'রাণী',
#   'আসার',
#   'কথা',
#   'সড়ক',
#   'পথে',
#   'কিন্তু',
#   'হেলিপ্যাড',
#   'রেডি',
#   'করতে',
#   'হবে',
#   '।',
#   'গণপূর্তের',
#   'নির্বাহী',
#   'প্রকৌশলী',
#   'মহোদয়কে',
#   'বললাম',
#   'স্টেডিয়ামে',
#   'হেলিপ্যাড',
#   'বানান',
#   '।',
#   'বানানো',
#   'হলো',
#   '।',
#   'মোটরকেড',
#   'এবং',
#   'নিরাপত্তার',
#   'দায়িত্বে',
#   'থাকা',
#   'অফিসারের',
#   'জন্য',
#   'প্রচুর',
#   'গাড়ি',
#   'লাগবে',
#   '।',
#   'করলাম',
#   'ম্যানেজ',
#   '।',
#   'এর',
#   'মাঝে',
#   'হঠাত',
#   'বলা',
#   'হলো',
#   'রাণী',
#   'যদি',
#   'লাঞ্চ',
#   'করতে',
#   'চায়',
#   'তাহলে',
#   'মেন্যু',
#   'কী',
#   'হবে',
#   '।',
#   'নেট',
#   'ঘেঁটে',
#   'ডাচদের',
#   'খাবারের',
#   'আইডিয়া',
#   'নিলাম',
#   '।',
#   'আমার',
#   'বউকেও',
#   'বললাম',
#   'হেল্প',
#   'করতে',
#   '।',
#   'যদিও',
#   'ওটা',
#   'পরে',
#   'আর',
#   'প্রয়োজন',
#   'হয়নি',
#   '।',
#   'রাণীর',
#   'জন্য',
#   'মেডিকেল',
#   'টিম',
#   'ফায়ার',
#   'সার্ভিস',
#   'ফুড',
#   'এক্সামিনার',
#   'সহ',
#   'সকল',
#   'কিছু',
#   'রেডি',
#   'রাখলাম',
#   '।',
#   'রাণীকে',
#   'আমাদের',
#   'জেলা',
#   'প্রশাসক',
#   'স্যার',
#   'নরসিংদী',
#   'জেলার',
#   'একটা',
#   'টোকেন',
#   'গিফট',
#   'দিবে',
#   '।',
#   'সেটাও',
#   'রেডি',
#   'করলাম',
#   ...],
#  ['নিজের',
#   'অজান্তেই',
#   'চায়ে',
#   'চুমুক',
#   'দিলাম',
#   '।',
#   'দিয়ে',
#   'মনে',
#   'হলো',
#   'সত্যি',
#   'এত',
#   'স্বাদের',
#   'চা',
#   'জীবনে',
#   'খাইনি',
#   '।',
#   'কেমন',
#   'নেশা',
#   'ধরানো',
#   'অপূর্ব',
#   'এক',
#   'পানীয়',
#   '।',
#   'চা',
#   'এ',
#   'রকমও',
#   'হতে',
#   'পারে',
#   '।',
#   'আমাদের',
#   'বাড়ির',
#   'পরই',
#   'দিগন্তব্যাপী',
#   'মাঠ',
#   '।',
#   'আমি',
#   'একা',
#   'থাকি',
#   'মাঠের',
#   'ধারের',
#   'একটা',
#   'ঘরে',
#   '।',
#   'রাত',
#   'জেগেও',
#   'ছবি',
#   'আঁকি',
#   '।',
#   'এক',
#   'রাতে',
#   'একটা',
#   'পরির',
#   'ছবি',
#   'আঁকলাম',
#   '।',
#   'শুধু',
#   'পাখনা',
#   'দুটো',
#   'রঙিন',
#   '।',
#   'ভারি',
#   'সুন্দর',
#   'হলো',
#   'ছবিটা',
#   '।',
#   'আহা',
#   'এ',
#   'রকম',
#   'একজন',
#   'পরি',
#   'যদি',
#   'আমার',
#   'বউ',
#   'হতো',
#   '।',
#   'বাইরে',
#   'শিউলি',
#   'ফুলের',
#   'মতো',
#   'জ্যোৎস্না',
#   '।',
#   'সুন্দর',
#   'হাওয়া',
#   'বইছে',
#   '।',
#   'আমি',
#   'ঘর',
#   'থেকে',
#   'বেরিয়ে',
#   'এলাম',
#   '।',
#   'মাঠের',
#   'দিকে',
#   'গিয়ে',
#   'একটু',
#   'ঘুরলাম',
#   '।',
#   'ঘরে',
#   'ফিরে',
#   'দেখলাম',
#   'এক',
#   'অদ্ভুত',
#   'দৃশ্য',
#   '।',
#   'আমি',
#   'আবার',
#   'হাসলাম',
#   '।',
#   'তিনি',
#   'আমার',
#   'হাসিটা',
#   'খেয়াল',
#   'করলেন',
#   '।',
#   'পাগলের',
#   'প্রলাপ',
#   'ভাবছেন',
#   '।',
#   'সেটাই',
#   'ভাবার',
#   'কথা',
#   '।',
#   'হাতে',
#   'আঁকা',
#   'ছবি',
#   'থেকে',
#   'পরির',
#   'পাখা',
#   'খুলে',
#   'টেবিলে',
#   'রাখা',
#   'হবে',
#   'এটা',
#   'কোনো',
#   'মানুষের',
#   'পক্ষে',
#   'মেনে',
#   'নেওয়া',
#   'সম্ভব',
#   'না',
#   '।',
#   'আমিও',
#   'মেনে',
#   'নিতে',
#   'পারছিলাম',
#   'না',
#   '।',
#   'এ',
#   'কী',
#   'করে',
#   'সম্ভব',
#   '।',
#   'আর',
#   'ভারি',
#   'সুন্দর',
#   'একটা',
#   'গন্ধ',
#   'আমার',
#   'ঘরে',
#   '।',
#   'তারপর',
#   'দেখি',
#   'ভাই',
#   'ছবিটা',
#   'জ্যান্ত',
#   'হয়ে',
#   'গেল',
#   '।',
#   'ক্যানভাস',
#   'থেকে',
#   'পরিটা',
#   'বেরিয়ে',
#   'এল',
#   '।',
#   'ছবিতে',
#   'তো',
#   'এইটুকু',
#   'সাইজ',
#   '।',
#   'আমার',
#   'দিকে',
#   'অপলক',
#   'চোখে',
#   'তাকিয়ে',
#   'আছে',
#   'সে',
#   '।',
#   'আমিও',
#   'তাকিয়ে',
#   'আছি',
#   '।',
#   'কথা',
#   'বলতে',
#   'পারছি',
#   'না',
#   '।',
#   'তার',
#   'একটা',
#   'সাইকেল',
#   'আছে',
#   '।',
#   'আমাকে',
#   'সাইকেলের',
#   'রডে',
#   'বসিয়ে',
#   'নিয়ে',
#   'যায়।',
#   'দাঁড়ান',
#   'তাকে',
#   'ফোন',
#   'করি',
#   '।',
#   'সে',
#   'এসে',
#   'আমাকে',
#   'নিয়ে',
#   'যাক',
#   '।\xa0'],
#  ['পাঞ্জাবির',
#   'পকেট',
#   'থেকে',
#   'অদ্ভুত',
#   'একটা',
#   'মোবাইল',
#   'ফোন',
#   'বের',
#   'করলেন',
#   'তিনি',
#   '।',
#   'সাইকেল',
#   'এসে',
#   'আমাদের',
#   'সামনে',
#   'থামল।',
#   'ভারি',
#   'একটা',
#   'সুগন্ধে',
#   'ভরে',
#   'গেল',
#   'চারদিক',
#   '।',
#   'ভদ্রলোক',
#   'রংতুলি',
#   'ইত্যাদি',
#   'গুছিয়ে',
#   'ব্যাগে',
#   'ভরলেন',
#   '।',
#   'ব্যাগ',
#   'বা',
#   'রংতুলি',
#   'কিছুই',
#   'আমি',
#   'দেখতে',
#   'পাচ্ছি',
#   'না',
#   '।',
#   'ভদ্রলোকের',
#   'অঙ্গভঙ্গি',
#   'দেখে',
#   'বুঝতে',
#   'পারছিলাম',
#   '।',
#   'তারপর',
#   'তিনি',
#   'অদৃশ্য',
#   'ক্যানভাস',
#   'থেকে',
#   'অদৃশ্য',
#   'ছবি',
#   'খুলে',
#   'হাতে',
#   'নিলেন',
#   '।',
#   'আপনার',
#   'সঙ্গে',
#   'গল্প',
#   'করে',
#   'খুব',
#   'মজা',
#   'পেলাম',
#   '।',
#   'বড়বাজারে',
#   'এক',
#   'তাঁতির',
#   'একখানা',
#   'দোকান',
#   'ছিল',
#   '।',
#   'একদিন',
#   'দোকানে',
#   'বেচাকেনা',
#   'করার',
#   'সময়',
#   'একটা',
#   'জরুরি',
#   'কাজে',
#   'করিম',
#   'এক',
#   'ছেলেকে',
#   'দোকানে',
#   'বসিয়ে',
#   'রেখে',
#   'তিনি',
#   'কিছুক্ষণের',
#   'জন্য',
#   'বাইরে',
#   'গেলেন',
#   '।',
#   'করিম',
#   'এক',
#   'ঘণ্টা',
#   'দোকানে',
#   'বসে',
#   'থাকল',
#   'কিন্তু',
#   'তবুও',
#   'দোকানদার',
#   'ফিরে',
#   'এল',
#   'না',
#   '।',
#   'এদিকে',
#   'ক্রেতারা',
#   'জিনিসপত্রের',
#   'জন্য',
#   'তাগাদা',
#   'দিতে',
#   'লাগল',
#   '।',
#   'করিম',
#   'বখশের',
#   'জিনিসপত্রের',
#   'দাম',
#   'জানা',
#   'ছিল',
#   'সে',
#   'কয়েকখানা',
#   'কাপড়',
#   'বিক্রি',
#   'করল',
#   '।',
#   'দুঃখের',
#   'বিষয়',
#   'সারা',
#   'দিন',
#   'চলে',
#   'গেল',
#   'তবুও',
#   'দোকানদার',
#   'ফিরে',
#   'এলো',
#   'না',
#   '।',
#   'করিম',
#   'অগত্যা',
#   'সেদিন',
#   'আর',
#   'বাড়ি',
#   'ফিরতে',
#   'পারল',
#   'না',
#   '।',
#   'দোকানদারের',
#   'অপেক্ষায়',
#   'সেখানেই',
#   'রাত্রি',
#   'যাপন',
#   'করল',
#   '।',
#   'পরের',
#   'দিন',
#   'যথাসময়ে',
#   'দোকান',
#   'খুলে',
#   'করিম',
#   'মালিকের',
#   'অপেক্ষা',
#   'করতে',
#   'লাগল',
#   'কিন্তু',
#   'মালিকের',
#   'সন্ধান',
#   'নেই',
#   '।',
#   'করিম',
#   'অগত্যা',
#   'নিজেই',
#   'দোকানে',
#   'বেচাকেনা',
#   'করতে',
#   'লাগল',
#   '।\xa0এভাবে',
#   'দুদিন',
#   'তিনদিন',
#   'শেষে',
#   'এক',
#   'মাস',
#   'কেটে',
#   'গেল',
#   '।',
#   'আঁতি',
#   'ফিরল',
#   'না',
#   '।',
#   'করিম',
#   'দোকানের',
#   'ভার',
#   'ফেলে',
#   'যাওয়া',
#   'অধর্ম',
#   'মনে',
#   'করে',
#   'বিশ্বস্ত',
#   'ভৃত্যের',
#   'মতো',
#   'কাজ',
#   'চালাতে',
#   'লাগল।',
#   'তাঁতি',
#   'যাদের',
#   'কাছে',
#   'ঋণী',
#   'ছিল',
#   'করিম',
#   'তাদের',
#   'সব',
#   'টাকা',
#   'পরিশোধ',
#   'করল',
#   '।',
#   'তাঁতির',
#   'হয়েই',
#   'সে',
#   'নতুন',
#   'কাপড়ের',
#   'চালান',
#   'এনে',
#   'দোকানের',
#   'আয়',
#   'ঠিক',
#   'রাখল',
#   '।',
#   'এক',
#   'বছর',
#   'অতিবাহিত',
#   'হয়ে',
#   'গেল',
#   '।',
#   'করিমের',
#   'আন্তরিক',
#   'চেষ্টায়',
#   'দোকানের',
#   'ক্রমেই',
#   'উন্নতি',
#   'হচ্ছিল',
#   '।',
#   'শেষে',
#   'এক',
#   'দোকানের',
#   'পরিবর্তে',
#   'তিনটি',
#   'দোকান',
#   'স্থাপিত',
#   'হলো',
#   '।',
#   'করিম',
#   'সব',
#   'দোকান',
#   'তাতির',
#   'নামে',
#   'চালাতে',
#   'লাগলো',
#   'লোকেরা',
#   'ভাবল',
#   'করিম',
#   'তাতির',
#   'দোকান',
#   'কিনে',
#   'নিয়েছে',
#   '।',
#   'করিমের',
#   'সম্মান',
#   'প্রতিপত্তি',
#   'ইত্যবসরে',
#   'খুব',
#   'বেড়ে',
#   'গেল',
#   '।\xa0'],
#  ['সে',
#   'সওদাগর',
#   'হয়ে',
#   'বিরাট',
#   'কারবার',
#   'চালাতে',
#   'লাগল',
#   '।',
#   'প্রায়',
#   'সাত',
#   'বছর',
#   'অতিবাহিত',
#   'হয়ে',
#   'গিয়েছে',
#   '।',
#   'একদিন',
#   'করিম',
#   'দোকানের',
#   'গদিতে',
#   'বসে',
#   'আছে',
#   '।',
#   'একজন',
#   'বুড়া',
#   'লাঠি',
#   'ভর',
#   'করে',
#   'তারই',
#   'দোকানের',
#   'সামনে',
#   'করিম',
#   'বলে',
#   'একটা',
#   'বালকের',
#   'খোজ',
#   'করছে',
#   '।',
#   'বুড়ার',
#   'পরনে',
#   'একখানা',
#   'ময়লা',
#   'কাপড়',
#   'রোগা',
#   'চেহারা',
#   'শরীর',
#   'একেবারে',
#   'ভেঙে',
#   'গিয়েছে',
#   '।',
#   'তাকে',
#   'পথের',
#   'ভিক্ষুক',
#   'বলে',
#   'মনে',
#   'হচ্ছিল',
#   '।',
#   'করিম',
#   'দৌড়ে',
#   'এসে',
#   'বুড়াকে',
#   'বুকের',
#   'সঙ্গে',
#   'আঁকড়ে',
#   'ধরে',
#   'বলল',
#   'আমি',
#   'হচ্ছি',
#   'সেই',
#   'করিম',
#   'এই',
#   'সাত',
#   'বছর',
#   'আমি',
#   'আপনার',
#   'দোকান',
#   'পাহারা',
#   'দিয়েছি',
#   '।',
#   'দয়া',
#   'করে',
#   'এখন',
#   'আপনি',
#   'আপনার',
#   'দোকানের',
#   'ভার',
#   'নিন',
#   'আমি',
#   'বিদায়',
#   'হই',
#   '।',
#   'করিমের',
#   'মহপ্রাণের',
#   'পরিচয়',
#   'পেয়ে',
#   'বৃদ্ধের',
#   'দুচোখ',
#   'দিয়ে',
#   'পানি',
#   'পড়তে',
#   'লাগল',
#   '।',
#   'বললেন',
#   'আমার',
#   'আর',
#   'কিছু',
#   'দরকার',
#   'নেই',
#   'এ',
#   'সবই',
#   'তোমার',
#   '।',
#   'আমার',
#   'এ',
#   'সংসারে',
#   'যারা',
#   'আপন',
#   'ছিল',
#   'সবাই',
#   'আমাকে',
#   'ছেড়ে',
#   'গেছে',
#   '।',
#   'এখন',
#   'তুমিই',
#   'আমার',
#   'আপন',
#   '।',
#   'সেই',
#   'সাত',
#   'বছর',
#   'আগের',
#   'কথা',
#   'এখান',
#   'থেকে',
#   'বেরিয়ে',
#   'পথে',
#   'সংবাদ',
#   'পেলাম',
#   'আমার',
#   'পত্নীর',
#   'সাংঘাতিক',
#   'পীড়া',
#   '।',
#   'কালবিলম্ব',
#   'না',
#   'করে',
#   'আমাকে',
#   'বাড়ি',
#   'যেতে',
#   'হয়েছিল',
#   '।',
#   'গিয়ে',
#   'দেখলাম',
#   'পত্নীর',
#   'মৃত্যু',
#   'হয়েছে',
#   '।',
#   'তার',
#   'মৃত্যুর',
#   'কয়েকদিন',
#   'পরে',
#   'ছেলে',
#   'দুটো',
#   'মারা',
#   'গেল',
#   '।',
#   'তারপর',
#   'নানা',
#   'দুর্বিপাকে',
#   'পড়ে',
#   'আমি',
#   'কিছুতেই',
#   'বাড়ি',
#   'ত্যাগ',
#   'করতে',
#   'পারলাম',
#   'না',
#   '।',
#   'তারপর',
#   'এই',
#   'দীর্ঘ',
#   'সময়',
#   'অতিবাহিত',
#   'হয়ে',
#   'গিয়েছে',
#   '।',
#   'এখন',
#   'আমার',
#   'কেউ',
#   'নেই',
#   '।',
#   'আত্মীয়',
#   'স্বজন',
#   'অর্থ',
#   'দেহের',
#   'বল',
#   'সব',
#   'হারিয়ে',
#   'এখন',
#   'আমি',
#   'পথের',
#   'ফকির',
#   'হয়েছি',
#   '।',
#   'অতি',
#   'দুঃখে',
#   'অনেক',
#   'আশা',
#   'নিরাশায়',
#   'মনে',
#   'হলো',
#   'দোকানে',
#   'গিয়ে',
#   'একবার',
#   'করিমের',
#   'সন্ধান',
#   'করি',
#   'তাকে',
#   'যদি',
#   'পাই',
#   'তার',
#   'কাছ',
#   'থেকে',
#   'দু',
#   'এক',
#   'টাকা',
#   'ভিক্ষে',
#   'নেব',
#   '।',
#   'দোকান',
#   'কি',
#   'আর',
#   'এতদিন',
#   'আছে',
#   '?',
#   'করিম',
#   'আমি',
#   'তোমাকে',
#   'এমন',
#   'রাজার',
#   'হালে',
#   'দেখব',
#   'এ',
#   'কখনো',
#   'মনে',
#   'করিনি',
#   '।',
#   'আর',
#   'তুমি',
#   'যে',
#   'এমন',
#   'করে',
#   'আমার',
#   'কাছে',
#   'পরিচয়',
#   'দিলে',
#   'এ',
#   'ভেবে',
#   'আমার',
#   'মনে',
#   'যে',
#   'কী',
#   'আনন্দ',
#   'হচ্ছে',
#   'তা',
#   'আর',
#   'কী',
#   'বলব',
#   '।',
#   'বলো',
#   'বাবা',
#   'তুমি',
#   'মানুষ',
#   'না',
#   'ফেরেশতা',
#   '।',
#   'করিম',
#   'সবিনয়ে',
#   'বলল',
#   'আপনি',
#   'আমার',
#   'পিতার',
#   'মতো',
#   'আমাকে',
#   'বিশ্বাস',
#   'করেছিলেন',
#   'সে',
#   'বিশ্বাসকে',
#   'আমি',
#   'রক্ষা',
#   'করতে',
#   'পেরেছি',
#   'এই',
#   'আমার',
#   'পক্ষে',
#   'ঢের',
#   '।',
#   'এর',
#   'বেশি',
#   'আমি',
#   'কিছু',
#   'আশা',
#   'করিনি',
#   '।\xa0তাঁতি',
#   'করিমের',
#   'হাত',
#   'থেকে',
#   'দোকানের',
#   'ভার',
#   'গ্রহণ',
#   'করলেন',
#   'না',
#   '।',
#   'জীবনে',
#   'তার',
#   'আর',
#   'বন্ধন',
#   'রইল',
#   'না',
#   '।',
#   'একটা',
#   'মাসিক',
#   'বন্দোত',
#   'করে',
#   'তিনি',
#   'অতঃপর',
#   'তীর্থে',
#   'চলে',
#   'গেলেন',
#   '।',
#   '\xa0লুৎফর',
#   'রহমান',
#   'মাগুরা',
#   'জেলায়',
#   'জন্মগ্রহণ',
#   'করেন',
#   '।',
#   'লেখাপড়া',
#   'শেষ',
#   'করে',
#   'প্রথম',
#   'জীবনে',
#   'কিছুদিন',
#   'শিক্ষকতা',
#   'করেন',
#   '।',
#   'পরে',
#   'ডাক্তারি',
#   'পেশা',
#   'গ্রহণ',
#   'করেন',
#   '।',
#   'তিনি',
#   'অনেক',
#   'উপদেশমূলক',
#   'প্রবন্ধগ্রন্থ',
#   'রচনা',
#   'করেন',
#   '।',
#   'এই',
#   'সৃষ্টিশীল',
#   'প্রাবন্ধিক',
#   'মৃত্যুবরণ',
#   'করেন',
#   '।',
#   'এক',
#   'তাতির',
#   'একটি',
#   'কাপড়ের',
#   'দোকান',
#   'ছিল',
#   '।',
#   'একদিন',
#   'জরুরি',
#   'কাজে',
#   'তিনি',
#   'দোকানের',
#   'বাইরে',
#   'গেলেন',
#   'দোকানের',
#   'দায়িত্ব',
#   'দিয়ে',
#   'গেলেন',
#   'করিম',
#   'নামের',
#   'এক',
#   'ছেলেকে',
#   '।',
#   'নানা',
#   'দুর্বিপাকে',
#   'পড়ে',
#   'দোকানি',
#   'দীর্ঘদিন',
#   'ফিরে',
#   'আসতে',
#   'পারলেন',
#   'না',
#   '।',
#   'করিম',
#   'সততার',
#   'সাথে',
#   'কাজ',
#   'করে',
#   'দোকানের',
#   'অনেক',
#   'উন্নতি',
#   'করল',
#   '।',
#   'ক্রমে',
#   'এক',
#   'দোকানের',
#   'পরিবর্তে',
#   'তিনটি',
#   'দোকান',
#   'স্থাপিত',
#   'হলো',
#   '।',
#   'প্রায়',
#   'সাত',
#   'বছর',
#   'পরে',
#   'হঠাৎ',
#   'দোকানি',
#   'ফিরে',
#   'এলেন',
#   '।',
#   'করিম',
#   'সাদরে',
#   'তাকে',
#   'বরণ',
#   'করে',
#   'দোকানের',
#   'দায়িত্ব',
#   'তার',
#   'হাতে',
#   'তুলে',
#   'দিতে',
#   'আগ্রহী',
#   'হলো',
#   '।',
#   'করিমের',
#   'মহৎ',
#   'প্রাণের',
#   'পরিচয়',
#   'পেয়ে',
#   'বৃদ্ধ',
#   'দোকানি',
#   'অভিভূত',
#   'হলেন',
#   '।',
#   'নিজের',
#   'জন্য',
#   'একটা',
#   'মাসিক',
#   'বন্দোবস্ত',
#   'করে',
#   'করিমের',
#   'হাতেই',
#   'দোকান',
#   'বুঝিয়ে',
#   'দিয়ে',
#   'তিনি',
#   'তীর্থে',
#   'চলে',
#   'গেলেন',
#   '।',
#   'বালক',
#   'তার',
#   'সততার',
#   'পুরস্কার',
#   'পেল',
#   '।',
#   'আমার',
#   'বাবা',
#   'মুক্তিযোদ্ধা',
#   '।',
#   'নয়',
#   'নম্বর',
#   'সেক্টরে',
#   'ক্যাপ্টেন',
#   'শাজাহানের',
#   'নেতৃত্বে',
#   'যে',
#   'বিশাল',
#   'মুক্তিবাহিনীর',
#   'দল',
#   'গড়ে',
#   'উঠে',
#   'বাবা',
#   'ছিলেন',
#   'তাদের',
#   'একজন',
#   '।',
#   'ক্যাপ্টেন',
#   'শাজাহান',
#   'ছিলেন',
#   'দুর্ধর্ষ',
#   'মুক্তিযোদ্ধা',
#   '।',
#   'বরিশালের',
#   'বিভিন্ন',
#   'জায়গায়',
#   'ছিল',
#   'তার',
#   'বাহিনীর',
#   'তৎপরতা',
#   '।',
#   'পাকিস্তানি',
#   'হানাদার',
#   'বাহিনীর',
#   'উপরে',
#   'যখন',
#   'তখন',
#   'আক্রমণ',
#   'চালিয়ে',
#   'ক্যাপ্টেন',
#   'শাজাহান',
#   'ও',
#   'তার',
#   'গ্রুপ',
#   'তাদের',
#   'নাজেহাল',
#   'করে',
#   'তুলতেন।',
#   'বাবা',
#   'ছিলেন',
#   'খুব',
#   'নামকরা',
#   'মুক্তিযোদ্ধা',
#   '।',
#   'তেমনি',
#   'সাহসী',
#   '।',
#   'বাবা',
#   'বয়সে',
#   'বড়',
#   'হলেও\xa0ক্যাপ্টেন',
#   'শাজাহান',
#   'বাবাকে',
#   'অত্যন্ত',
#   'স্নেহ',
#   'করতেন',
#   '।',
#   'একবার',
#   'হলো',
#   'কী',
#   'খালের',
#   'ওপারে',
#   'ক্যাম্প',
#   'বসাল',
#   'পাকিস্তানি',
#   'মিলিটারি',
#   '।',
#   'তাদের',
#   'সঙ্গে',
#   'অনেক',
#   'রাজাকার',
#   '।',
#   'রাজাকাররা',
#   'তখন',
#   'অবস্থা',
#   'খারাপ',
#   'বুঝে',
#   'মিলিটারিদের',
#   'সাথে',
#   'সাথে',
#   'ঘুরত',
#   '।',
#   'ভাবত',
#   'বুঝি',
#   'অস্ত্রের',
#   'সাথে',
#   'সাথে',
#   'থাকলে',
#   'তারা',
#   'নিরাপদে',
#   'থাকবে',
#   '।',
#   'যা',
#   'হোক',
#   'ক্যাপ্টেন',
#   'শাজাহান',
#   'স্থির',
#   'করলেন',
#   'রাতের',
#   'বেলা',
#   'খাল',
#   'পেরিয়ে',
#   'তাদের',
#   'আক্রমণ',
#   'করবেন',
#   '।',
#   'সেই',
#   'হিসেবে',
#   'আমার',
#   'সাহসী',
#   'বাবাকে',
#   'আগের',
#   'দিন',
#   'রেকি',
#   'করতে',
#   'পাঠানো',
#   'হল',
#   '।',
#   'বাবার',
#   'পরিবেশজ্ঞান',
#   'ছিল',
#   'খুব',
#   'তীক্ষ',
#   '।',
#   'সন্ধ্যেবেলা',
#   'গোপনে',
#   'খাল',
#   'পার',
#   'হয়ে',
#   'বাবা',
#   'ওপারে',
#   'গিয়ে',
#   'দেখলেন',
#   'বিস্তীর্ণ',
#   'মাঠ',
#   '।',
#   'বাবা',
#   'জঙ্গলের',
#   'ধার',
#   'ঘেঁষে',
#   'মাঠ',
#   'পার',
#   'হতে',
#   'লাগলেন',
#   '।',
#   'আর',
#   'সেই',
#   'সময়',
#   'ঘটল',
#   'বিস্ফোরণ',
#   '।',
#   'মাঠের',
#   'দুধারে',
#   'ছিল',
#   'মাইন',
#   'পাতা',
#   'যা',
#   'বাবা',
#   'ঘুণাক্ষরেও',
#   'টের',
#   'পাননি',
#   '।',
#   'মাইনের',
#   'উপরে',
#   'সরাসরি',
#   'পা',
#   'ফেলতেই',
#   'বিস্ফোরণে',
#   'বাবার',
#   'দুটি',
#   'পাই',
#   'হাঁটুর',
#   'নিচ',
#   'থেকে',
#   'উড়ে',
#   'গেল',
#   '।',
#   'বাবা',
#   'জ্ঞান',
#   'হারালেন',
#   '।',
#   'বাবার',
#   'পেছনে',
#   'ছিলেন',
#   'আর',
#   'একজন',
#   'মুক্তিযোদ্ধা',
#   '।',
#   'তিনি',
#   'বাবাকে',
#   'টেনে',
#   'হেঁচড়ে',
#   'নিয়ে',
#   'গেলেন',
#   'গহিন',
#   'জঙ্গলের',
#   'ভিতরে',
#   '।',
#   'সেখান',
#   'থেকে',
#   'পরে',
#   'তাদের',
#   'উদ্ধার',
#   'করা',
#   'হলো',
#   '।',
#   'বাবার',
#   'মুক্তিযোদ্ধা',
#   'জীবনের',
#   'সেখানেই',
#   'হলো',
#   'ইতি',
#   '।\xa0এই',
#   'ঘটনার',
#   'পর',
#   'বাবাকে',
#   'সীমান্তের',
#   'ক্যাম্পে',
#   'পাঠিয়ে',
#   'দেওয়া',
#   'হলো',
#   '।',
#   'দীর্ঘদিন',
#   'চিকিৎসা',
#   'হলো',
#   'বাবার',
#   '।',
#   'দুটো',
#   'নকল',
#   'পা',
#   'তৈরি',
#   'করে',
#   'দেয়া',
#   'হলো',
#   'বাবাকে',
#   '।',
#   'কাঠের',
#   'নকল',
#   'পা',
#   '।',
#   'হাতে',
#   'লাঠি',
#   'নিয়ে',
#   'কাঠের',
#   'পা',
#   'লাগিয়ে',
#   'বাবা',
#   'আমার',
#   'নতুন',
#   'করে',
#   'হাঁটতে',
#   'শিখলেন',
#   '।',
#   'আস্তে',
#   'আস্তে',
#   '।',
#   'বাবা',
#   'যখন',
#   'মুক্তিযুদ্ধে',
#   'আমি',
#   'তখন',
#   'খুব',
#   'ছোট্ট',
#   '।',
#   'এক',
#   'বছর',
#   'হয়েছে',
#   'কি',
#   'না',
#   'সন্দেহ',
#   '।',
#   'তাই',
#   'মুক্তিযুদ্ধ',
#   'থেকে',
#   'ফিরে',
#   'এসে',
#   'বাবা',
#   'আমাকে',
#   'কোলে',
#   'তুলতেই',
#   'আমি',
#   'ভ্যাক',
#   'করে',
#   'কেদে',
#   'সারা',
#   '।',
#   'আর',
#   'বাবাও',
#   'আমাকে',
#   'কোলে',
#   'তুলে',
#   'অপ্রতুত',
#   '।',
#   'তারপর',
#   'আস্তে',
#   'আস্তে',
#   'বাবার',
#   'সাথে',
#   'ভাব',
#   'হলো',
#   '।',
#   'এখন',
#   'আমার',
#   'সবচেয়ে',
#   'বড়',
#   'বন্ধু',
#   'বাবা',
#   '।',
#   'আর',
#   'বাবার',
#   'বন্ধু',
#   'আমি',
#   '।',
#   'বাবাকে',
#   'আমি',
#   'খুব',
#   'ভালোবাসি',
#   '।',
#   'তবু',
#   'মনে',
#   'হয়',
#   'কোথায়',
#   'যেন',
#   'ফাক',
#   'থেকে',
#   'যায়',
#   '।\xa0আমাদের',
#   'বাড়িতে',
#   'শুধু',
#   'আমি',
#   'আর',
#   'বাবা',
#   'থাকি',
#   '।',
#   'সরকার',
#   'কিছু',
#   'অনুদান',
#   'দেন',
#   '।',
#   'আর',
#   'বাবা',
#   'বাড়ি',
#   'বসে',
#   'বিভিন্ন',
#   'প্রতিষ্ঠানের',
#   'জন্যে',
#   'কি',
#   'সব',
#   'রিপোর্ট',
#   'তৈরি',
#   'করেন',
#   '।',
#   'এই',
#   'দিয়ে',
#   'আমাদের',
#   'সংসার',
#   'চলে',
#   '।',
#   'দাদা',
#   'বাবার',
#   'জন্যে',
#   'ছোট',
#   'একটা',
#   'বাড়ি',
#   'রেখে',
#   'গেছেন',
#   '।',
#   'আমাদের',
#   'তাই',
#   'বাড়িভাড়া',
#   'লাগে',
#   'না',
#   '।',
#   'আমার',
#   'বয়স',
#   'ষোল',
#   '।',
#   'বাবার',
#   'বয়স',
#   'তেতাল্লিশ',
#   '।',
#   'আমি',
#   'এইবার',
#   'মাধ্যমিক',
#   'পরীক্ষা',
#   'দিয়েছি',
#   '।',
#   'পরীক্ষা',
#   'মোটামুটি',
#   'হয়েছে',
#   '।',
#   'খুব',
#   'একটা',
#   'লেখাপড়া',
#   'করতে',
#   'আমার',
#   'মন',
#   'চায়',
#   'না',
#   '।',
#   'বাবা',
#   'মন',
#   'খারাপ',
#   'করবেন',
#   'ভয়ে',
#   'আমি',
#   'পড়ি',
#   '।',
#   'আমাদের',
#   'বাড়িটা',
#   'কী',
#   'নির্জন',
#   '।',
#   'খাচায়',
#   'একটা',
#   'ময়না',
#   'পাখি',
#   'পুষেছি',
#   '।',
#   'বেশির',
#   'ভাগ',
#   'সময়',
#   'আমি',
#   'তার',
#   'সঙ্গেই',
#   'কথা',
#   'বলি',
#   '।',
#   'তাকে',
#   'ছোলা',
#   'খেতে',
#   'দিই',
#   '।',
#   'সে',
#   'আমাকে',
#   'নয়ন',
#   'ও',
#   'নয়ন',
#   'বলে',
#   'ডাকে',
#   '।',
#   'আমার',
#   'ডাকনাম',
#   'নয়ন',
#   '।',
#   'বাবা',
#   'সারাটা',
#   'সকাল',
#   'বইপত্তর',
#   'নিয়ে',
#   'ঘাঁটাঘাঁটি',
#   'করেন',
#   '।',
#   'বাসায়',
#   'একটা',
#   'কাজের',
#   'বুয়া',
#   'আছে',
#   '।',
#   'সে',
#   'রান্নাবান্না',
#   'করে',
#   '।\xa0আমি',
#   'আর',
#   'বাবা',
#   'খাই',
#   '।',
#   'দুপুরে',
#   'বাবা',
#   'ঘুমাতে',
#   'চলে',
#   'গেলে',
#   'সারা',
#   'বাড়িতে',
#   'আমি',
#   'একা',
#   '।',
#   'আমার',
#   'ভালো',
#   'লাগে',
#   '।',
#   'বিকেলে',
#   'আমার',
#   'বন্ধু',
#   'নিয়ামত',
#   'আসে',
#   '।',
#   'আমরা',
#   'বাড়ির',
#   'সামনের',
#   'মাঠে',
#   'কোর্ট',
#   'কেটে',
#   'ব্যাডমিন্টন',
#   'খেলি',
#   '।',
#   'সন্ধ্যের',
#   'আগে',
#   'আগে',
#   'চলে',
#   'যায়',
#   '।',
#   'তারপর',
#   'আমি',
#   'বাড়ির',
#   'মধ্যে',
#   'ঢুকে',
#   'দেখি',
#   'বাবা',
#   'আমার',
#   'জন্যে',
#   'চা',
#   'নাস্তা',
#   'সাজিয়ে',
#   ...],
#  ['একদিন',
#   'ছেলেকে',
#   'এই',
#   'কথা',
#   'জিজ্ঞেস',
#   'করতেই',
#   'ছেলেটি',
#   'হতভম্ভ',
#   'হয়ে',
#   'যায়',
#   '।',
#   'ও',
#   'বাবার',
#   'পাশে',
#   'বসে',
#   'বলে',
#   'বাবা',
#   'তুমিতো',
#   'আমাদের',
#   'মতো',
#   'ছেলেদের',
#   'পা',
#   'ঠিক',
#   'রাখতে',
#   'মুক্তিযুদ্ধে',
#   'নিজের',
#   'পা',
#   'হারিয়েছিলে',
#   '।',
#   'তুমি',
#   'তোমার',
#   'পা',
#   'অক্ষত',
#   'রাখতে',
#   'চাইলে',
#   'আমাদের',
#   'মতো',
#   'ছেলেরা',
#   'তাদের',
#   'পা',
#   'হারাত',
#   'বাবা',
#   '।',
#   'আমি',
#   'তোমাকে',
#   'ছেড়ে',
#   'কোনদিন',
#   'কোথাও',
#   'যাব',
#   'না',
#   '।',
#   'ছেলের',
#   'কথা',
#   'শুনে',
#   'মুক্তিযোদ্ধা',
#   'বাবা',
#   'গভীর',
#   'আবেগে',
#   'কেঁপে',
#   'উঠেন',
#   '।',
#   'উঠোনের',
#   'কোণার',
#   'দিকে',
#   'বিশাল',
#   'যে',
#   'গাছটা',
#   'সেটা',
#   'একটা',
#   'নিমগাছ',
#   '।',
#   'নিমপাতা',
#   'স্বাস্থ্যের',
#   'জন্য',
#   'ভালো',
#   '।',
#   'চারপাশের',
#   'গাছের',
#   'এত',
#   'সবুজ',
#   'রঙের',
#   'পাতা',
#   '।',
#   'ঘাসের',
#   'বনে',
#   'ছোট',
#   'ছোট',
#   'রঙিন',
#   'ফুল',
#   'আবার',
#   'মনটাকে',
#   'অন্যরকম',
#   'করে',
#   'দেয়',
#   '।',
#   'কিছুক্ষণ',
#   'আগে',
#   'শোনা',
#   'যাচ্ছিলো',
#   'ঘুঘুর',
#   'ডাক',
#   '।',
#   'একটু',
#   'আগে',
#   'একটা',
#   'রঙিন',
#   'পাখিও',
#   'চোখে',
#   'পড়েছে',
#   '।',
#   'পাখির',
#   'পালকে',
#   'অনেক',
#   'রং',
#   '।',
#   'নাম',
#   'না',
#   'জানা',
#   'পাখিটার',
#   'একটা',
#   'নাম',
#   'ঠিক',
#   'করে',
#   'ফেলে',
#   'অমি',
#   '।',
#   'পাখির',
#   'নাম',
#   'রঙিলা',
#   '।\xa0ঠিক',
#   'সে',
#   'সময়',
#   'চোখে',
#   'পড়ল',
#   'নীল',
#   'রঙের',
#   'হাফপ্যান্ট',
#   'আর',
#   'নীল',
#   'রঙের',
#   'হাফশার্ট',
#   'পরা',
#   'একটা',
#   'লোক।',
#   'একটা',
#   'কাঠের',
#   'বাক্স',
#   'ঠেলে',
#   'সামনে',
#   'নিয়ে',
#   'আসছে',
#   '।',
#   'লোকটা',
#   'হেঁড়ে',
#   'গলায়',
#   'ডাক',
#   'দিচ্ছে',
#   'আইসক্রিম',
#   '।\xa0এই',
#   'জঙ্গলের',
#   'মধ্যে',
#   'লোকটা',
#   'আইসক্রিম',
#   'কার',
#   'কাছে',
#   'বিক্রি',
#   'করবে',
#   '?',
#   'প্রথমেই',
#   'প্রশ্নটা',
#   'অমির',
#   'মাথায়',
#   'এলেও',
#   'পরে',
#   'মনে',
#   'হলো',
#   'লোকটা',
#   'কোথায়',
#   'কার',
#   'কাছে',
#   'আইসক্রিম',
#   'বিক্রি',
#   'করবে',
#   'তার',
#   'জানার',
#   'দরকার',
#   'কী',
#   '?',
#   'বরং',
#   'লোকটাকে',
#   'ডেকে',
#   'একটা',
#   'আইসক্রিম',
#   'কেনা',
#   'যায়',
#   '।',
#   'জানালা',
#   'দিয়ে',
#   'অমি',
#   'ডাক',
#   'দেয়',
#   'আইসক্রিমঅলাকে',
#   '।\xa0দরজা',
#   'খুলে',
#   'বাইরে',
#   'দাঁড়াতেই',
#   'আইসক্রিমঅলা',
#   'বলে',
#   'কী',
#   'আইসক্রিম',
#   'খাবেন',
#   '?',
#   'বাপরে',
#   'এই',
#   'জঙ্গলে',
#   'আইসক্রিম',
#   'পাওয়া',
#   'যাচ্ছে',
#   'এটাতো',
#   'বেশি',
#   '।',
#   'তারপর',
#   'আবার',
#   'কী',
#   'আইসক্রিম',
#   'পাওয়া',
#   'যাবে',
#   '।',
#   'তার',
#   'পছন্দেরও',
#   'সুযোগ',
#   'রয়েছে',
#   '।',
#   'ভীষণ',
#   'অবাক',
#   'হয়',
#   'অমি',
#   '।',
#   'কী',
#   'ধরনের',
#   'আইসক্রিম',
#   'রয়েছে',
#   '?',
#   'আপনি',
#   'কি',
#   'নতুন',
#   'এসেছেন',
#   '?',
#   'কালাম',
#   'সাহেব',
#   'কোথায়',
#   '?',
#   'আপনি',
#   'কালাম',
#   'সাহেবকে',
#   'চিনেন',
#   '?',
#   'তিনি',
#   'আপনার',
#   'কে',
#   'হন',
#   '?',
#   'আপনি',
#   'বেড়াতে',
#   'এসেছেন',
#   '?',
#   'ঠিক',
#   'বেড়াতে',
#   'নয়',
#   '।',
#   'তবে',
#   'ময়মনসিংহ',
#   'যাচ্ছিলাম',
#   '।',
#   'গাড়ি',
#   'নষ্ট',
#   'হয়ে',
#   'যাওয়ায়',
#   'কালাম',
#   'সাহেবের',
#   'এখানে',
#   'এসেছেন',
#   '।',
#   'আজই',
#   'কি',
#   'চলে',
#   'যাবেন',
#   '?',
#   'আজ',
#   'নয়',
#   'কাল',
#   'ফিরব',
#   '।',
#   'অমি',
#   'বলল',
#   'জায়গাটা',
#   'খুব',
#   'সুন্দর',
#   '।',
#   'আগে',
#   'আরও',
#   'সুন্দর',
#   'ছিল',
#   '।',
#   'সেটা',
#   'কী',
#   'রকম',
#   '?',
#   'এই',
#   'বাড়িটা',
#   'জমিদার',
#   'রায়',
#   'বল্লভ',
#   'রায়ের',
#   '।',
#   'রায়',
#   'বল্লভ',
#   'রায়',
#   '।\xa0খুব',
#   'কম',
#   'জমিদারই',
#   'আছে',
#   'যাদের',
#   'নামের',
#   'আগে',
#   'পরে',
#   'দুবার',
#   'রায়',
#   'লেখা',
#   'হয়',
#   '।',
#   'সেই',
#   'জমিদার',
#   'এখন',
#   'কোথায়',
#   '?',
#   'এই',
#   'বাড়ির',
#   'ভিতরেই',
#   'আছে',
#   '।',
#   'মানে',
#   '?',
#   'বসার',
#   'ঘরে',
#   '।',
#   'জমিদার',
#   'সাহেবের',
#   'একটা',
#   'বিশাল',
#   'ছবি',
#   'টাঙানো',
#   'আছে',
#   '।',
#   'আমার',
#   'পুরো',
#   'বাড়ি',
#   'দেখা',
#   'হয়',
#   'নি',
#   '।',
#   'সময়',
#   'পেলে',
#   'দেখে',
#   'নিবেন',
#   '।',
#   'আমার',
#   'আইসক্রিম',
#   'দিলেন',
#   'না',
#   '?',
#   'মুখে',
#   'যদিও',
#   'লোকটা',
#   'বলল',
#   'তাইতো',
#   '।',
#   'কিন্তু',
#   'তারপরই',
#   'আবার',
#   'অমিকে',
#   'বলল',
#   'একসময়',
#   'এই',
#   'বাড়িটার',
#   'অনেক',
#   'জৌলুস',
#   'ছিল',
#   '।',
#   'সেটা',
#   'অবশ্য',
#   'আমি',
#   'কাল',
#   'রাতেই',
#   'বুঝেছি',
#   '।',
#   'কেমন',
#   'করে',
#   '?',
#   'মামা',
#   'বললেন',
#   'বাড়িটা',
#   'অনেক',
#   'বড়',
#   '।',
#   'এত',
#   'রাতে',
#   'দেখার',
#   'দরকার',
#   'নেই',
#   '।',
#   'তাই',
#   'বুঝি',
#   'খেয়েদেয়ে',
#   'তাড়াতাড়ি',
#   'শুয়ে',
#   'পড়েছেন',
#   '?',
#   'বাড়ির',
#   'ভিতর',
#   'একটা',
#   'ফোন',
#   'রয়েছে',
#   '।',
#   'অবশ্য',
#   'ফোনটা',
#   'এখন',
#   'নষ্ট',
#   '।',
#   'নষ্ট',
#   'হবারই',
#   'কথা',
#   '।',
#   'এই',
#   'বাড়ির',
#   'অনেক',
#   'কিছুই',
#   'এখন',
#   'নষ্ট',
#   '।\xa0কী',
#   'রকম',
#   '?',
#   'পুরো',
#   'বাড়ির',
#   'প্রত্যেক',
#   'ঘরে',
#   'বড়',
#   'দেয়াল',
#   'ঘড়ি',
#   'ছিল',
#   '।',
#   'সেগুলো',
#   'সবই',
#   'নষ্ট',
#   '।',
#   'বসার',
#   'ঘরে',
#   'টানা',
#   'পাখা',
#   'ছিল',
#   '।',
#   'সেটাই',
#   'এখন',
#   'কেউ',
#   'চালায়',
#   'না',
#   '।',
#   'টানা',
#   'পাখা',
#   'নষ্ট',
#   'হয়',
#   'কখনো',
#   '?',
#   'নষ্ট',
#   'হয়',
#   'না',
#   '।',
#   'কিন্তু',
#   'দড়িগুলো',
#   'সব',
#   'পুরনো',
#   'হয়ে',
#   'ছিড়ে',
#   'গেছে',
#   '।',
#   'বাড়িটার',
#   'কেউ',
#   'কোনো',
#   'যত্ন',
#   'নেয়',
#   'না',
#   'কেন',
#   '?\xa0সে',
#   'প্রশ্ন',
#   'তো',
#   'আমারও',
#   '।',
#   'এই',
#   'ধরনের',
#   'বাড়ির',
#   'সরকারের',
#   'উচিত',
#   'রক্ষণাবেক্ষণের',
#   'ব্যবস্থা',
#   'করা',
#   '।',
#   'আপনার',
#   'মতো',
#   'সবাই',
#   'যদি',
#   'ব্যাপারটা',
#   'বুঝতে',
#   'পারত',
#   '।',
#   'যাই',
#   'হোক',
#   'গলাটা',
#   'একদম',
#   'শুকিয়ে',
#   'গেছে',
#   '।',
#   'একগ্লাস',
#   'পানি',
#   'খাওয়াবেন',
#   '?',
#   'ভারি',
#   'মজার',
#   'ব্যাপার',
#   'তো',
#   'কোনো',
#   'আইসক্রিমআলা',
#   'পানি',
#   'খেতে',
#   'চায়',
#   '?',
#   'এমন',
#   'কথা',
#   'কখনো',
#   'শোনেনি',
#   'অমি',
#   '।',
#   'অবশ্য',
#   'ময়রা',
#   'নিজের',
#   'মিষ্টি',
#   'খায়',
#   'না',
#   '।',
#   'সুতরাং',
#   'আইসক্রিমঅলা',
#   'নিজের',
#   'আইসক্রিম',
#   'নাও',
#   'খেতে',
#   'পারে',
#   '।',
#   'আপনি',
#   'দাঁড়ান',
#   '।',
#   'আমি',
#   'পানি',
#   'এনে',
#   'দিচ্ছি',
#   '।',
#   'বাড়িতে',
#   'আর',
#   'কেউ',
#   'নেই',
#   '?',
#   'আবদুল',
#   'চাচা',
#   'ছিলেন',
#   '।',
#   'তিনিও',
#   'বাজারে',
#   'গিয়েছেন',
#   '।',
#   'দুঃখিত',
#   'আমার',
#   'জন্যে',
#   'আপনাকে',
#   'কষ্ট',
#   'করতে',
#   'হচ্ছে',
#   '।\xa0পানি',
#   'খেতে',
#   'চেয়েছেন',
#   'তো',
#   'কষ্টের',
#   'কী',
#   'আছে',
#   '?',
#   'অমি',
#   'ঘরের',
#   'ভিতরে',
#   'চলে',
#   'যায়',
#   '।',
#   'ওর',
#   'ঘরে',
#   'জগের',
#   'মধ্যে',
#   'পানি',
#   'রাখা',
#   '।',
#   'জগ',
#   'থেকে',
#   'গ্লাসে',
#   'পানি',
#   'রাখতে',
#   'গিয়ে',
#   'অবাক',
#   'অমি',
#   '।',
#   'কী',
#   'আশ্চর্য',
#   'জগ',
#   'একদম',
#   'খালি',
#   '।',
#   'অথচ',
#   'ওর',
#   'স্পষ্ট',
#   'মনে',
#   'আছে',
#   'আবদুল',
#   'চাচা',
#   'জগ',
#   'ভরে',
#   'পানি',
#   'রেখে',
#   'বলে',
#   'গিয়েছিল',
#   'এই',
#   'জগে',
#   'পানি',
#   'রইল',
#   '।',
#   'বিকেলে',
#   'আবার',
#   'পানি',
#   'ফোটাব',
#   '।',
#   'অমি',
#   'বলেছিল',
#   'আর',
#   'দরকার',
#   'হবে',
#   'না',
#   '।',
#   'এক',
#   'জগ',
#   'পানিতে',
#   'আমার',
#   'কাল',
#   'সকাল',
#   'পর্যন্ত',
#   'চলবে',
#   '।',
#   'আবদুল',
#   'চাচার',
#   'কথায়',
#   'বোঝা',
#   'যাচ্ছে',
#   'ঘরে',
#   'আর',
#   'খাবার',
#   'পানি',
#   'নেই',
#   '।',
#   'বাথরুমের',
#   'কলের',
#   'দিকে',
#   'চোখ',
#   'পড়ে',
#   'অমির',
#   '।',
#   'কিন্তু',
#   'কলের',
#   'প্যাচ',
#   'খুলছে',
#   'না',
#   '।',
#   'এত',
#   'বড়',
#   'বাড়ি',
#   '।',
#   'কোথায়',
#   'খুঁজবে',
#   'পানি',
#   '।',
#   'অমি',
#   'খালি',
#   'গ্লাসটা',
#   'নিয়ে',
#   'আবার',
#   'বাইরে',
#   'এসে',
#   'দাঁড়ায়',
#   '।',
#   'কী',
#   'পানি',
#   'পেলেন',
#   '?',
#   'মাথা',
#   'নিচু',
#   'করে',
#   'থাকে',
#   'অমি',
#   '।',
#   'দেখলেন',
#   'তো',
#   'এত',
#   'বড়',
#   'বাড়ি',
#   'কিন্তু',
#   'একফোঁটা',
#   'পানি',
#   'পেলেন',
#   'না',
#   '।',
#   'কী',
#   'দুর্ভাগ্য',
#   '।',
#   'সত্যি',
#   'ব্যাপারটা',
#   'বড়',
#   'দুর্ভাগ্যের',
#   '।',
#   'এই',
#   'দুর্ভাগ্য',
#   'এড়াতে',
#   'পারে',
#   'নি',
#   'রাজা',
#   'রায়',
#   'বল্লভ',
#   'রায়ও',
#   '।',
#   'রাজার',
#   'আবার',
#   'দুর্ভাগ্য',
#   'হয়',
#   'কী',
#   'করে',
#   '?',
#   'সেই',
#   'তো',
#   'কথা',
#   '।',
#   'যে',
#   'রাজার',
#   'নামের',
#   'ডাকে',
#   'সব',
#   'প্রজারা',
#   'এক',
#   'হয়ে',
#   'যেত',
#   'সেই',
#   'রাজার',
#   'ভাগ্যের',
#   'এমন',
#   'পরিণতি',
#   'হবে',
#   'তা',
#   'কেউ',
#   'ভাবে',
#   'নি',
#   '।\xa0কী',
#   'হয়েছিল',
#   'রাজার',
#   '?',
#   'একাত্তরের',
#   'কথা',
#   'নিশ্চয়ই',
#   'আপনি',
#   'জানেন',
#   '।',
#   'আমাদের',
#   'স্বাধীনতা',
#   'যুদ্ধের',
#   'সময়',
#   'ঘটনাটা',
#   'ঘটেছিল',
#   '।',
#   'কী',
#   'ঘটনা',
#   '?\xa0ঠিক',
#   'সেসময়',
#   'হঠাৎ',
#   'করে',
#   'গাড়ির',
#   'হর্নের',
#   'শব্দ',
#   'শোনা',
#   'যায়',
#   '।',
#   'ড্রাইভার',
#   'বোধহয়',
#   'গাড়ি',
#   'নিয়ে',
#   'ফিরে',
#   'আসছে',
#   '।',
#   'অমি\xa0আইসক্রিম’অলাকে',
#   'বলল',
#   'আমাদের',
#   'গাড়ি',
#   'ফিরে',
#   'আসছে',
#   '।',
#   'গাড়িতে',
#   'পানির',
#   'বোতল',
#   'আছে',
#   '।',
#   'আপনাকে',
#   'পানি',
#   'দেব',
#   '।',
#   'ঠিক',
#   'আছে',
#   'তবে',
#   'বোধহয়',
#   'সেটা',
#   'লাগবে',
#   'না',
#   '।',
#   'অদ্ভুতভাবে',
#   'লোকটি',
#   'দুই',
#   'চাকাঅলা',
#   'আইসক্রিমের',
#   'কাঠের',
#   'বাক্সটা',
#   'নিয়ে',
#   'কিছু',
#   'বলার',
#   'আগেই',
#   'নিমিষের',
#   'মধ্যে',
#   'অদৃশ্য',
#   'হয়ে',
#   'যায়',
#   '।',
#   'ড্রাইভার',
#   'এসে',
#   'চাবি',
#   'দিয়ে',
#   'চলে',
#   'যায়',
#   '।',
#   'আর',
#   'কী',
#   'আশ্চর্য',
#   'আবার',
#   'আইসক্রিমঅলা',
#   'আইসক্রিমের',
#   'বাক্স',
#   'নিয়ে',
#   'উপস্থিত',
#   'হয়',
#   'অমির',
#   'সামনে',
#   '।',
#   'হঠাৎ',
#   'করেই',
#   'অমির',
#   'মনে',
#   'হলো',
#   'একটু',
#   'আগে',
#   'যে',
#   'আইসক্রিমঅলাকে',
#   'অমি',
#   'দেখেছিল',
#   'সেই',
#   'একই',
#   'আইসক্রিম’অলা।',
#   'কিন্তু',
#   'তার',
#   'বয়স',
#   'বেড়ে',
#   'গেছে',
#   'অনেক',
#   '।',
#   'আগের',
#   'আইসক্রিমঅলা',
#   'ছিল',
#   'কিনা',
#   'সেটাও',
#   'মনে',
#   'করতে',
#   'পারছে',
#   'না',
#   'অমি',
#   '।',
#   'আপনি',
#   'আবার',
#   'ফিরে',
#   'এলেন',
#   'যে',
#   '।',
#   'আপনার',
#   'আইসক্রিমটা',
#   'দিতে',
#   'ভুলে',
#   'গেছি',
#   '।',
#   'আমিও',
#   'পানি',
#   'দিতে',
#   'ভুলে',
#   'গেছিলাম',
#   '।',
#   'এই',
#   'কথা',
#   'বলে',
#   'অমি',
#   'গাড়ির',
#   'দিকে',
#   'এগোয়',
#   '।',
#   'আইসক্রিমঅলা',
#   'বলে',
#   'এখন',
#   'পানি',
#   'আর',
#   'খেতে',
#   'ইচ্ছা',
#   'করছে',
#   'না',
#   '।',
#   'বরং',
#   'আপনি',
#   'কী',
#   'আইসক্রিম',
#   'যেন',
#   'খাবেন',
#   'বলেছিলেন',
#   '।',
#   'যখন',
#   'আমি',
#   'তার',
#   'ড্রাইভারের',
#   'সঙ্গে',
#   'কথা',
#   'বলছিল',
#   'তখন',
#   'ঐটুকু',
#   'সময়ের',
#   'মধ্যে',
#   'লোকটা',
#   'কোথায়',
#   'গিয়েছিল',
#   '?',
#   'অমির',
#   'কথাটা',
#   'মনে',
#   'হওয়ার',
#   'কারণ',
#   'আইসক্রিমঅলা',
#   'লোকটি',
#   'হঠাৎ',
#   'যেন',
#   'খুব',
#   'পরিশ্রান্ত',
#   'হয়ে',
#   'গেছে',
#   '।',
#   'কথা',
#   'বলতে',
#   'গিয়ে',
#   'হাঁপাচ্ছে',
#   '।',
#   'আপনি',
#   'আমাকে',
#   'রাজা',
#   'রায়',
#   'বল্লভ',
#   'রায়ের',
#   'দুর্ভাগ্যের',
#   'কথা',
#   'বলতে',
#   'যাচ্ছিলেন',
#   '।',
#   'আমি',
#   'শুনতে',
#   'পাচ্ছি',
#   'না',
#   '।',
#   'একটু',
#   'জোরে',
#   'বলবেন',
#   '?',
#   'চিৎকার',
#   'করে',
#   'অমি',
#   'বলে',
#   ...]]

# %%
final_token = []
for i in range(len(token)):
    list_token = token[i]
    for tok in list_token:
        final_token.append(tok.lower().strip())
        
total_token = len(final_token)
print(f"Total token no: {total_token}")
print("-------------------------------")
final_token[:20]
# Out:
# Total token no: 154898
# -------------------------------
# ['কর্পোরেশনের',
#  'দোষ',
#  'তো',
#  'আছে',
#  '।',
#  'কিন্তু',
#  'আমরা',
#  'যে',
#  'সুযোগ',
#  'বুঝে',
#  'হাজার',
#  'হাজার',
#  'কোটি',
#  'টাকার',
#  'ট্যাক্স',
#  'ফাকি',
#  'দিয়ে',
#  'আসছি',
#  'সেটাও',
#  'আমরা']

# %%
from collections import Counter
counter = Counter(final_token)
counter
# Out:
# Counter({'।': 4233,
#          'করে': 1326,
#          'এই': 1202,
#          'আর': 1124,
#          'না': 1090,
#          'একটা': 944,
#          'আমি': 930,
#          'আমার': 839,
#          'থেকে': 825,
#          'না।': 799,
#          'ও': 690,
#          'আমাদের': 667,
#          'তার': 613,
#          'এক': 599,
#          'আমরা': 581,
#          'যে': 546,
#          'সে': 545,
#          'কিন্তু': 544,
#          'কথা': 537,
#          'তিনি': 529,
#          'কী': 516,
#          'করতে': 510,
#          'জন্য': 506,
#          'সেই': 465,
#          'নিয়ে': 458,
#          'কোনো': 448,
#          'হয়ে': 441,
#          'দিয়ে': 419,
#          'সঙ্গে': 408,
#          'এ': 396,
#          'অনেক': 393,
#          'আপনি': 376,
#          'করা': 375,
#          'মনে': 374,
#          'তো': 356,
#          'কি': 348,
#          'হবে': 343,
#          'এবং': 340,
#          'সব': 334,
#          'আছে': 332,
#          'আপনার': 332,
#          'হয়': 325,
#          'তখন': 312,
#          'ছিল': 310,
#          'সময়': 305,
#          '?': 305,
#          'বলে': 301,
#          'কিছু': 292,
#          'তাঁর': 290,
#          'বা': 289,
#          'এখন': 288,
#          'হলো': 270,
#          'না,': 267,
#          'তা': 264,
#          'খুব': 259,
#          'তাদের': 254,
#          'যদি': 253,
#          'আগে': 252,
#          'ভালো': 251,
#          'একজন': 248,
#          'মানুষ': 246,
#          'এর': 242,
#          'বাবা': 237,
#          'আবার': 235,
#          'মতো': 225,
#          'বড়': 225,
#          'বললেন,': 224,
#          'মধ্যে': 218,
#          'দিন': 216,
#          'কেউ': 213,
#          'চলে': 212,
#          'হবে।': 208,
#          'এটা': 206,
#          'নিজের': 202,
#          'দিতে': 197,
#          'যেন': 197,
#          'শুরু': 194,
#          'পর': 191,
#          'তাই': 191,
#          'কাছে': 190,
#          'যায়': 188,
#          'তুমি': 188,
#          'মানুষের': 187,
#          'দেখা': 187,
#          'এমন': 185,
#          'তবে': 183,
#          'দুই': 183,
#          'হতে': 182,
#          'করার': 181,
#          'হয়ে': 181,
#          'একটু': 180,
#          'বেশি': 180,
#          'আমাকে': 179,
#          'সেটা': 178,
#          'একটি': 178,
#          'কাজ': 177,
#          'আছে।': 176,
#          'যেতে': 174,
#          'বছর': 170,
#          'যখন': 170,
#          'পানি': 170,
#          'দেশে': 167,
#          'দিকে': 167,
#          'নাম': 166,
#          'বলল,': 166,
#          'ঠিক': 165,
#          'দেখে': 165,
#          'বলতে': 163,
#          'শেষ': 161,
#          'শুধু': 161,
#          'ধরে': 161,
#          'পরে': 160,
#          'এসে': 157,
#          'ওই': 156,
#          'যায়।': 156,
#          'দেখতে': 155,
#          'তারা': 154,
#          'এত': 151,
#          'তারপর': 151,
#          'তাকে': 150,
#          'দেশের': 149,
#          'টাকা': 147,
#          'দেওয়া': 146,
#          'পারে': 146,
#          'গেল': 145,
#          'হয়।': 144,
#          'নেই।': 144,
#          'বড়': 143,
#          'প্রথম': 142,
#          'বসে': 141,
#          'কত': 141,
#          'যা': 140,
#          'কেন': 140,
#          'সবাই': 139,
#          'পা': 139,
#          'হাতে': 138,
#          'তাহলে': 137,
#          'তোমার': 136,
#          'গিয়ে': 134,
#          'হলে': 133,
#          'সামনে': 131,
#          'ফিরে': 131,
#          'নেই': 129,
#          'এবার': 128,
#          'পড়ে': 125,
#          'বাবার': 125,
#          'বের': 125,
#          'বাংলাদেশের': 124,
#          'যাবে': 123,
#          'থাকে': 123,
#          'করেন': 123,
#          'ছবি': 117,
#          'হয়': 117,
#          'করে।': 117,
#          'সাথে': 116,
#          'ছোট': 115,
#          'আজ': 114,
#          'নতুন': 113,
#          'হিসেবে': 112,
#          'গল্প': 111,
#          'বলা': 110,
#          'কখনো': 109,
#          'হচ্ছে': 109,
#          'তাঁদের': 109,
#          'দিয়ে': 106,
#          'নাকি': 105,
#          'কে': 105,
#          'বেশ': 104,
#          'হাত': 104,
#          'হয়,': 103,
#          'নিতে': 102,
#          'গেলে': 102,
#          'হয়েছে।': 102,
#          'হাজার': 100,
#          'কারণ': 99,
#          'রকম': 99,
#          'পারেন': 98,
#          'ঘুরে': 98,
#          'যাওয়ার': 97,
#          'একদিন': 97,
#          'মারা': 97,
#          'নিয়ে': 97,
#          'তাঁরা': 97,
#          'পাওয়া': 96,
#          'আরও': 96,
#          'পর্যন্ত': 94,
#          'মা': 94,
#          '': 92,
#          'ঢাকা': 92,
#          'বই': 92,
#          'বিভিন্ন': 91,
#          'বললেন': 91,
#          'কিংবা': 91,
#          'অন্য': 91,
#          'এখানে': 91,
#          'তৈরি': 91,
#          'কম': 90,
#          'আপনাকে': 90,
#          'রাজা': 90,
#          'ঘরে': 90,
#          'নয়।': 89,
#          'এসব': 88,
#          'সুন্দর': 88,
#          'বাইরে': 87,
#          'দেশ': 87,
#          'কোনো': 87,
#          'যেমন': 86,
#          'যায়': 86,
#          'হলো,': 86,
#          'ফোন': 85,
#          'করি': 85,
#          'আছে,': 85,
#          'তো': 85,
#          'কেমন': 84,
#          'ছিলেন': 84,
#          'তাঁকে': 84,
#          'সময়': 83,
#          'ক্ষেত্রে': 82,
#          'চেষ্টা': 80,
#          'মন': 80,
#          'সারা': 80,
#          'গেছে।': 80,
#          'নানা': 79,
#          'উত্তর': 79,
#          'খবর': 79,
#          'আসলে': 78,
#          'ভুল': 78,
#          'একবার': 78,
#          'ধরনের': 77,
#          'গেছে': 76,
#          'বিশাল': 76,
#          'মুখ': 76,
#          'প্রায়': 76,
#          'খেতে': 76,
#          'তাহার': 76,
#          'কাজেই': 75,
#          'ছাড়া': 75,
#          'নেই,': 75,
#          'একই': 74,
#          'দুটো': 74,
#          'রেখে': 74,
#          'সবচেয়ে': 74,
#          'শুনে': 74,
#          'পাশে': 74,
#          'গাড়ি': 73,
#          'হয়েছে': 73,
#          'প্রশ্ন': 73,
#          'হবে,': 73,
#          'তুলে': 72,
#          'পথে': 72,
#          'বাবলু': 72,
#          'গেল।': 72,
#          'স্যার': 71,
#          'মানে': 71,
#          'মাঝে': 70,
#          'নিজেকে': 70,
#          'খারাপ': 70,
#          'বুঝতে': 70,
#          'ওপর': 70,
#          'বন্ধু': 70,
#          'সেখানে': 70,
#          'লেখা': 70,
#          'পারে।': 70,
#          'ধীরে': 69,
#          'থেকেই': 69,
#          'মুখে': 69,
#          'বলল': 69,
#          'আসতে': 69,
#          'করেন।': 69,
#          'বাংলাদেশ': 68,
#          'বিশেষ': 68,
#          'চেয়ে': 68,
#          'থাকতে': 68,
#          'ওপরে': 68,
#          'মাথা': 68,
#          'ছিল।': 68,
#          'রয়েছে': 67,
#          'প্রতি': 67,
#          'জীবন': 67,
#          'তাতে': 67,
#          'এরপর': 67,
#          'যায়,': 67,
#          'কষ্ট': 66,
#          'কিছুই': 66,
#          'হঠাৎ': 66,
#          'বাড়ি': 66,
#          'অমি': 66,
#          'হলো।': 66,
#          'যারা': 65,
#          'কোন': 65,
#          'চোখে': 65,
#          'রাখা': 65,
#          'থাকবে': 64,
#          'বন্ধ': 64,
#          'ব্যবহার': 64,
#          'উঠে': 64,
#          'কারণ,': 64,
#          'আসে': 63,
#          'থাকা': 63,
#          'করবেন': 63,
#          'হয়তো': 63,
#          'পথ': 63,
#          'তিন': 63,
#          'ঘটনা': 62,
#          'ব্যবস্থা': 61,
#          'কাজে': 61,
#          'জীবনে': 61,
#          'যাচ্ছে': 61,
#          'কৌতুক': 61,
#          'ধরা': 60,
#          'মোবাইল': 60,
#          'পুরো': 59,
#          'যাওয়া': 59,
#          'ছেলে': 59,
#          'নিচে': 59,
#          'যাবে।': 59,
#          'সবার': 58,
#          'রাখতে': 58,
#          'মনের': 58,
#          'বিশ্বাস': 58,
#          'বাড়ির': 58,
#          'করিয়া': 58,
#          'চাই': 57,
#          'সেদিন': 57,
#          'ভাই': 57,
#          'যাব': 57,
#          'করিম': 57,
#          'বিক্রি': 57,
#          'তোমাকে': 57,
#          'জানি': 56,
#          'লাগবে': 56,
#          'ওর': 56,
#          'পারেন।': 56,
#          'করি।': 56,
#          'করে,': 56,
#          'যাচ্ছে।': 56,
#          'শেষে': 55,
#          'থাকে।': 55,
#          'চোখ': 55,
#          'রাজার': 55,
#          'কেন?': 55,
#          'বলেছেন,': 55,
#          'হওয়ার': 54,
#          'লাগল': 54,
#          'ভালোবাসা': 53,
#          'হতো': 53,
#          'মাছ': 53,
#          'জানা': 52,
#          'ঘড়ি': 52,
#          'সবুজ': 52,
#          'বাংলা': 52,
#          'পানির': 52,
#          'ভোট': 52,
#          'মায়ের': 51,
#          'নেওয়া': 51,
#          'বৃষ্টি': 51,
#          'বাড়ি': 51,
#          'খাবার': 51,
#          'ঘণ্টা': 51,
#          'নামে': 51,
#          'দরকার': 51,
#          'বলেন,': 51,
#          '১০': 51,
#          'খেয়ে': 50,
#          'পেয়ে': 50,
#          'পাবেন': 50,
#          'উপর': 50,
#          'প্রকাশ': 50,
#          'খুলে': 50,
#          'কোথাও': 50,
#          'পৃথিবীর': 50,
#          'আপনারা': 50,
#          'দল': 49,
#          'বললাম': 49,
#          'ফেলে': 49,
#          'মাস': 49,
#          'কারণে': 49,
#          'পড়ে': 49,
#          'তবু': 49,
#          'পারি': 49,
#          'নয়,': 49,
#          'বছরের': 48,
#          'করলাম': 48,
#          'কারও': 48,
#          'সাদা': 48,
#          'শিক্ষা': 48,
#          'নেমে': 48,
#          'জিনিস': 48,
#          'করছে': 48,
#          'শুনতে': 48,
#          'দাঁড়িয়ে': 48,
#          'দোকানের': 48,
#          'ফেসবুক': 48,
#          'আজকে': 47,
#          'আশা': 47,
#          'কিনে': 47,
#          'দিলে': 47,
#          'আগের': 47,
#          'মানুষকে': 47,
#          'আলো': 47,
#          'পার': 47,
#          'পাহাড়ের': 47,
#          'নাই।': 47,
#          'বিশ্ববিদ্যালয়ের': 46,
#          'নষ্ট': 46,
#          'আছেন': 46,
#          'করবে': 46,
#          'বাসায়': 46,
#          'দেখি': 46,
#          'খেলা': 46,
#          'বহু': 46,
#          'হয়েছে,': 46,
#          'হলেও': 45,
#          'কাউকে': 45,
#          'লাগে': 45,
#          'পছন্দ': 45,
#          'রাতে': 45,
#          'এগিয়ে': 45,
#          'জানতে': 45,
#          'কেটে': 45,
#          'যাঁরা': 45,
#          'করলে': 45,
#          'লোক': 45,
#          'বলে,': 45,
#          'করছে।': 45,
#          'কথা।': 45,
#          'ছিল,': 45,
#          'সরকারের': 44,
#          'খুবই': 44,
#          'পারবেন': 44,
#          'ওরা': 44,
#          'পাঁচ': 44,
#          'যান': 44,
#          'দেখার': 44,
#          'বেরিয়ে': 44,
#          'ঈদের': 44,
#          'থাকলে': 44,
#          'আগেই': 44,
#          'নামের': 44,
#          'শহরে': 44,
#          'চাইলে': 44,
#          'আইসক্রিম': 44,
#          'অবশ্যই': 43,
#          'ভুলে': 43,
#          'জায়গা': 43,
#          'মাধ্যমে': 43,
#          'জীবনের': 43,
#          'গেলেন': 43,
#          'রাস্তার': 43,
#          'শব্দ': 43,
#          'পরের': 43,
#          'গিয়ে': 43,
#          'ভাগ': 43,
#          'সুযোগ': 42,
#          'সরকারি': 42,
#          'রঙের': 42,
#          'এখনো': 42,
#          'বরং': 42,
#          'অবশ্য': 42,
#          'শিশু': 42,
#          'দিনের': 42,
#          'আমিও': 42,
#          'দিল': 42,
#          'আনন্দ': 42,
#          'খুঁজে': 42,
#          'সত্যি': 42,
#          'দোকান': 42,
#          'হয়েছে': 42,
#          'মন্ত্রী': 42,
#          'ভালো': 42,
#          'হচ্ছে।': 42,
#          'থাকে,': 42,
#          'মাথায়': 41,
#          'যেকোনো': 41,
#          'দূর': 41,
#          'রাতের': 41,
#          'যাতে': 41,
#          'ভরে': 41,
#          'দিনে': 41,
#          'স্কুলে': 41,
#          'পরীক্ষা': 41,
#          'করল': 41,
#          'ডেকে': 41,
#          'বাংলাদেশে': 41,
#          'রায়': 41,
#          'দিন।': 41,
#          'প্রশ্নপত্র': 41,
#          'কোটি': 40,
#          'বিশ্ববিদ্যালয়': 40,
#          'ওদের': 40,
#          'আসার': 40,
#          'কাজের': 40,
#          'বেঁচে': 40,
#          'ঘুরতে': 40,
#          'ইচ্ছা': 40,
#          'সেখান': 40,
#          'ক্লাস': 40,
#          'দুটি': 40,
#          'যাই': 40,
#          'ভেতরে': 40,
#          'যার': 40,
#          'হতো।': 40,
#          'না?': 40,
#          'আপনাদের': 40,
#          'অবাক': 39,
#          'চেহারা': 39,
#          'ফলে': 39,
#          'বাস': 39,
#          'চার': 39,
#          'ভেঙে': 39,
#          'করেছে': 39,
#          'বাবাকে': 39,
#          'আবদুল': 39,
#          'হইতে': 39,
#          'কানে': 39,
#          'আরেকটা': 39,
#          'নিজে': 38,
#          'এপ্লাই': 38,
#          'বিষয়ে': 38,
#          'বাকি': 38,
#          'সমস্যা': 38,
#          'পাশাপাশি': 38,
#          'সকালে': 38,
#          'দেওয়ার': 38,
#          'গাছের': 38,
#          'চা': 38,
#          'রাত': 38,
#          'কোথায়': 38,
#          'মাত্র': 38,
#          'প্রকৃতির': 38,
#          'প্রধান': 38,
#          'গাধা': 38,
#          'কিছুটা': 37,
#          'অপেক্ষা': 37,
#          'চায়': 37,
#          'পেছনে': 37,
#          'একা': 37,
#          'ছোট্ট': 37,
#          'ভীষণ': 37,
#          'দিলেন': 37,
#          'সরকার': 37,
#          'হয়।': 37,
#          'আসবে': 36,
#          'ব্যাপারটা': 36,
#          'থাকেন': 36,
#          'বিশ্ববিদ্যালয়ে': 36,
#          'ভালোবাসার': 36,
#          'একদম': 36,
#          'অধিকার': 36,
#          'দুজন': 36,
#          'ছেড়ে': 36,
#          'বলার': 36,
#          'ঘুম': 36,
#          'উঠতে': 36,
#          'হাতের': 36,
#          'গুরুত্বপূর্ণ': 36,
#          'হাঁটতে': 36,
#          'সকাল': 36,
#          'ঢুকে': 36,
#          'উচিত': 36,
#          'পারে,': 36,
#          'পড়তে': 35,
#          'অনেকেই': 35,
#          'হোক': 35,
#          'ভাল': 35,
#          'নয়': 35,
#          'ঈদ': 35,
#          'কয়েক': 35,
#          'সম্ভব': 35,
#          'গেলাম': 35,
#          'বাসে': 35,
#          'পারবে': 35,
#          'সালে': 35,
#          'লিখে': 35,
#          'দলের': 35,
#          'আস্তে': 35,
#          'জিজ্ঞেস': 35,
#          'লোকটা': 35,
#          'পুরোনো': 35,
#          'পাহাড়': 35,
#          'করবে।': 35,
#          'বললাম,': 35,
#          'টাকা।': 35,
#          'সবকিছু': 34,
#          'কালো': 34,
#          'রইল': 34,
#          'তেমনি': 34,
#          'পরিবারের': 34,
#          'সাহায্য': 34,
#          'মিনিট': 34,
#          'ঢাকার': 34,
#          'গত': 34,
#          'সাধারণ': 34,
#          'ফেসবুকে': 34,
#          'একমাত্র': 34,
#          'দেব': 34,
#          'ব্যক্তি': 34,
#          'প্রশ্নের': 34,
#          'পুলিশ': 34,
#          'পারি।': 34,
#          'করেছে।': 34,
#          'বাঙালি': 34,
#          'পড়ে।': 34,
#          'ডাক্তার': 34,
#          'ভিন্ন': 33,
#          'জায়গায়': 33,
#          'তাকিয়ে': 33,
#          'হারিয়ে': 33,
#          'দেন': 33,
#          'পায়ে': 33,
#          'নীল': 33,
#          'ছাত্র': 33,
#          'খুশি': 33,
#          'মুখের': 33,
#          'নি': 33,
#          'কবিতা': 33,
#          'প্রথমে': 33,
#          'যেখানে': 33,
#          'ভাড়া': 33,
#          'শহরের': 33,
#          'জন্য।': 33,
#          'কবি': 33,
#          'লাখ': 33,
#          'ইত্যাদি': 32,
#          'দিক': 32,
#          'স্বপ্ন': 32,
#          'ভয়': 32,
#          'নদীর': 32,
#          'সত্য': 32,
#          'করলেন': 32,
#          'পথের': 32,
#          'আসা': 32,
#          'লম্বা': 32,
#          'ছেড়ে': 32,
#          'রকমের': 32,
#          'তোর': 32,
#          'স্বাধীন': 32,
#          'চোখের': 32,
#          'এমনকি': 32,
#          'হইয়া': 32,
#          'শেখ': 32,
#          'ক্ষমতা': 32,
#          'বলছেন,': 32,
#          'সম্পর্কে': 31,
#          'পেতে': 31,
#          'থাকার': 31,
#          'ইতিহাস': 31,
#          'নিজ': 31,
#          'মেনে': 31,
#          'লাভ': 31,
#          'এভাবে': 31,
#          'তুই': 31,
#          'বেলা': 31,
#          'নিশ্চয়ই': 31,
#          'এতে': 31,
#          'রাস্তায়': 31,
#          'কাঠের': 31,
#          'বাড়িতে': 31,
#          'ভিতর': 31,
#          'লোকে': 31,
#          'গরু': 31,
#          'বিখ্যাত': 31,
#          'ফল': 31,
#          'ভারতের': 31,
#          'সেসব': 31,
#          'কথা,': 31,
#          'যিনি': 31,
#          'করল।': 31,
#          'শিক্ষক': 30,
#          'কার': 30,
#          'একে': 30,
#          'আছি': 30,
#          'জানে': 30,
#          'কঠিন': 30,
#          'এসেছেন': 30,
#          'তেমন': 30,
#          'স্কুলের': 30,
#          'রাস্তা': 30,
#          'পাশের': 30,
#          'হাজির': 30,
#          'শাস্তি': 30,
#          'ঢাকায়': 30,
#          'ঘর': 30,
#          'সাইকেল': 30,
#          'মুক্তিযোদ্ধা': 30,
#          'গেছেন': 30,
#          'পরীক্ষার': 30,
#          'পানিতে': 30,
#          'চাষি': 30,
#          'নাই': 30,
#          'সহজ': 30,
#          'বুদ্ধিমান': 30,
#          'নিজেদের': 30,
#          'পাহাড়ি': 30,
#          'টিকিট': 30,
#          'করুন।': 30,
#          'কেবল': 30,
#          'বারবার': 30,
#          'ফোনে': 30,
#          'বিরুদ্ধে': 30,
#          'ফাঁস': 30,
#          'প্রেসিডেন্ট': 30,
#          'পেলে': 29,
#          'ভর্তি': 29,
#          'যদিও': 29,
#          'অর্থ': 29,
#          'আশ্চর্য': 29,
#          'ভেতর': 29,
#          'যত': 29,
#          'বোধ': 29,
#          'করব': 29,
#          'রক্ষা': 29,
#          'ভিডিও': 29,
#          'বাড়ির': 29,
#          'বউ': 29,
#          'এনে': 29,
#          'প্রায়': 29,
#          'মৃত্যু': 29,
#          'নয়': 29,
#          'পাওয়া': 29,
#          'মামা': 29,
#          'করেছেন': 29,
#          'একসঙ্গে': 29,
#          'দেন।': 29,
#          'চাই।': 29,
#          'বলে।': 29,
#          'শিল্পী': 29,
#          'করেন,': 29,
#          'আরেক': 29,
#          'মতো': 29,
#          'বুঝে': 28,
#          'টাকার': 28,
#          'দেয়': 28,
#          'বানানো': 28,
#          'হেঁটে': 28,
#          'দ্রুত': 28,
#          'ভেবে': 28,
#          'পড়া': 28,
#          'কিছুক্ষণ': 28,
#          'কোথায়': 28,
#          'শরীর': 28,
#          'অন্যান্য': 28,
#          'হওয়া': 28,
#          'ছেলেকে': 28,
#          'চালাতে': 28,
#          'একেবারে': 28,
#          'আকাশে': 28,
#          'সাহেব': 28,
#          'চাচা': 28,
#          'ভাবে': 28,
#          'আমেরিকার': 28,
#          'লুঙ্গি': 28,
#          'অভিজ্ঞতা': 27,
#          'নম্বর': 27,
#          'দারুণ': 27,
#          'হাসি': 27,
#          'দ্বিতীয়': 27,
#          'অন্যতম': 27,
#          'দাম': 27,
#          'দুধ': 27,
#          'দেবেন': 27,
#          'এলাকার': 27,
#          'পাই': 27,
#          'লক্ষ': 27,
#          'মৃত্যুর': 27,
#          'অবস্থা': 27,
#          'লাগে।': 27,
#          'যাবেন': 27,
#          'অনেকে': 27,
#          'প্রমাণ': 27,
#          'বদলে': 27,
#          'মিলে': 27,
#          'শহর': 27,
#          'করলেন।': 27,
#          'করেছেন।': 27,
#          'কী?': 27,
#          'প্রাচীন': 27,
#          'আসে।': 27,
#          'না।’': 27,
#          'রংপুর': 27,
#          'ভয়ে': 26,
#          'বলেই': 26,
#          'অত্যন্ত': 26,
#          'সাধারণত': 26,
#          'অর্ধেক': 26,
#          'মূল': 26,
#          'বিশ্বের': 26,
#          'জেলার': 26,
#          'রোজ': 26,
#          'কারো': 26,
#          'সামাজিক': 26,
#          'ছুটে': 26,
#          'শারীরিক': 26,
#          'কিছুদিন': 26,
#          'এসেছে': 26,
#          'বাড়িতে': 26,
#          'চলতে': 26,
#          'ঘন': 26,
#          'যুদ্ধ': 26,
#          'লিখতে': 26,
#          'খালি': 26,
#          'পান': 26,
#          'আসছে': 26,
#          'আইসক্রিমঅলা': 26,
#          'ঘরের': 26,
#          'অংশ': 26,
#          'আয়নার': 26,
#          'আগুন': 26,
#          'পৃথিবীতে': 26,
#          'দূরে': 26,
#          'জন': 26,
#          'আনা': 26,
#          'করব।': 26,
#          'হচ্ছে,': 26,
#          'নবান্ন': 26,
#          'প্রকাশিত': 26,
#          'করিতে': 26,
#          'তাহা': 26,
#          'গেছে,': 26,
#          'যান।': 26,
#          'আম্মা': 26,
#          'উঁচু': 26,
#          'ডলার': 26,
#          'ইঁদুর': 26,
#          'এটি': 25,
#          'যেটা': 25,
#          'খাবারের': 25,
#          'মানসিক': 25,
#          'অবস্থায়': 25,
#          'বয়ে': 25,
#          'কখন': 25,
#          'কাগজে': 25,
#          'বিয়ে': 25,
#          'দীর্ঘ': 25,
#          'কাল': 25,
#          'মাথার': 25,
#          'ঘটে': 25,
#          'দোকানে': 25,
#          'উপরে': 25,
#          'জ্ঞান': 25,
#          'সামনের': 25,
#          'বোঝা': 25,
#          'বল্লভ': 25,
#          'অথচ': 25,
#          'বাদশাহ': 25,
#          'নাই,': 25,
#          'নির্বাচন': 25,
#          'যেত।': 25,
#          'যায়।': 25,
#          'দেখি,': 25,
#          'বৃষ্টির': 25,
#          'বলছে,': 25,
#          'করি,': 25,
#          'হয়েছিল।': 25,
#          'আচ্ছা,': 25,
#          'সেটাও': 24,
#          'দিবে': 24,
#          'অন্যের': 24,
#          'পৃথিবী': 24,
#          'সুবিধা': 24,
#          'পক্ষে': 24,
#          'ছয়': 24,
#          'কমে': 24,
#          'আলোর': 24,
#          'বানিয়ে': 24,
#          'মোটামুটি': 24,
#          'ছেলের': 24,
#          'নিজেই': 24,
#          'কথার': 24,
#          'ছেলেটা': 24,
#          'অনলাইনে': 24,
#          'সময়ের': 24,
#          'সাত': 24,
#          'পাগল': 24,
#          'লাগল।': 24,
#          'পুরস্কার': 24,
#          'জন্যে': 24,
#          'স্বাধীনতা': 24,
#          'মাথায়': 24,
#          'চিৎকার': 24,
#          'ধীরেন': 24,
#          'ভাবতে': 24,
#          'বখশিশ': 24,
#          'রান্না': 24,
#          'অন্তত': 24,
#          'করেছেন,': 24,
#          'করেছি।': 24,
#          'মানুষদের': 24,
#          'পাকিস্তানের': 24,
#          'মানুষ।': 24,
#          'গেলাম।': 24,
#          'কীভাবে': 24,
#          'হয়নি।': 24,
#          'বিল': 24,
#          'চিঠি': 24,
#          '২০': 24,
#          'হলো': 24,
#          'চাই,': 24,
#          'পরিবর্তন': 23,
#          'অফার': 23,
#          'লেটার': 23,
#          'চাকরি': 23,
#          'সকল': 23,
#          'নিশ্চিত': 23,
#          'দ্বারা': 23,
#          'ধারণা': 23,
#          'শত': 23,
#          'করুন': 23,
#          'রাজি': 23,
#          'গাছ': 23,
#          'আসল': 23,
#          'সেরে': 23,
#          'ফুলের': 23,
#          'ধরতে': 23,
#          'গান': 23,
#          'অল্প': 23,
#          'হয়েছিল': 23,
#          'মাঠ': 23,
#          'অতি': 23,
#          'পাকিস্তানি': 23,
#          'বুঝি': 23,
#          'বেশির': 23,
#          'চুপ': 23,
#          'হন': 23,
#          'দাবি': 23,
#          'আসিয়া': 23,
#          'মুহূর্তে': 23,
#          'করছেন': 23,
#          'ঘুমিয়ে': 23,
#          'উপহার': 23,
#          'রেকর্ড': 23,
#          'বছরে': 23,
#          'মেয়ে': 23,
#          'করছি।': 23,
#          'অঞ্চলের': 23,
#          'নরম': 23,
#          'নেতা': 23,
#          'বাংলার': 23,
#          'গেলেন।': 23,
#          'কিলোমিটার': 23,
#          '‘আমি': 23,
#          'জবাব': 23,
#          'পরিচয়': 23,
#          'বলেছিলেন,': 23,
#          'গবেষণা': 23,
#          'কেন,': 23,
#          'ভোট': 23,
#          'পড়ার': 22,
#          'মজা': 22,
#          'ফুল': 22,
#          'বিয়ের': 22,
#          'বাতাস': 22,
#          'করেই': 22,
#          'শিশুদের': 22,
#          'দিঘির': 22,
#          'গ্রামের': 22,
#          'ভেসে': 22,
#          'ইংরেজি': 22,
#          'বিষয়': 22,
#          'রচনা': 22,
#          'খরচ': 22,
#          'হাসান': 22,
#          'ভদ্রলোক': 22,
#          'আপন': 22,
#          'কাছ': 22,
#          'করেছিলেন': 22,
#          'উদ্ধার': 22,
#          'পাখির': 22,
#          'হেসে': 22,
#          'মত': 22,
#          'দিল।': 22,
#          'বাজান': 22,
#          'ফেলা': 22,
#          'প্রতিটি': 22,
#          'ওখানে': 22,
#          'সিদ্ধান্ত': 22,
#          'হোটেল': 22,
#          'গাড়ির': 22,
#          'ট্রেন': 22,
#          'উপভোগ': 22,
#          'দিয়ে।': 22,
#          'থেকে।': 22,
#          'রবীন্দ্রনাথ': 22,
#          'তা-ই': 22,
#          'টেলিভিশন': 22,
#          'বৃত্তি': 21,
#          'বয়স': 21,
#          'পাওয়ার': 21,
#          'প্রয়োজন': 21,
#          'রে': 21,
#          'রং': 21,
#          'সেরা': 21,
#          'প্রচণ্ড': 21,
#          'সমস্ত': 21,
#          'আরেকজন': 21,
#          'কর': 21,
#          'অতিরিক্ত': 21,
#          'পেছন': 21,
#          'গল্পটা': 21,
#          'গরম': 21,
#          ...})

# %%
counter.get
# Out:
# <function Counter.get(key, default=None, /)>

# %%
# from the dictionary just get only the key: 
sorted_val = sorted(counter,key=counter.get,reverse=True)
print(sorted_val[:5])
print(len(sorted_val))
# Out:
# ['।', 'করে', 'এই', 'আর', 'না']
# 28475

# %%
vocab = ["UNK","PAD"] + sorted_val[:10000]
len(vocab)
# Out:
# 10002

# %%
vocab_size = len(vocab)
word_to_idx = { word:idx for idx, word in enumerate(vocab)}
list(word_to_idx.items())[:5]
# Out:
# [('UNK', 0), ('PAD', 1), ('।', 2), ('করে', 3), ('এই', 4)]

# %%
idx_to_word = { idx:word for idx,word in enumerate(vocab)}
dict(list(idx_to_word.items())[:5])
# Out:
# {0: 'UNK', 1: 'PAD', 2: '।', 3: 'করে', 4: 'এই'}

# %%
# we took only 10000, other token will be unkwon in final token:
unk_id = word_to_idx["UNK"]
unk_id
# Out:
# 0

# %%
final_idx = [word_to_idx.get(token,unk_id)  for token in final_token]
print(f"total size of final token: {len(final_idx)}")
final_idx[-10:-1]
# Out:
# total size of final token: 154898
# [563, 5716, 2, 418, 359, 365, 930, 2439, 2]

# %%
seq_length=30
sequences = []
next_words = []
for i in range(len(final_idx)-seq_length):
    sequences.append(final_idx[i:(i+seq_length)])
    next_words.append(final_idx[i+seq_length])


# total number of sequence:
print(f"Total number of sequence : {len(sequences)}")
print(f"Total number of next_words : {len(next_words)}")
# Out:
# Total number of sequence : 154868
# Total number of next_words : 154868

# %%
class CustomDataset(Dataset):
    def __init__(self,sequences,next_words):
        super().__init__()
        self.seq = torch.tensor(data=sequences,device=device,dtype=torch.long)
        self.nex = torch.tensor(data=next_words,device=device,dtype=torch.long)
        
    def __getitem__(self,idx):
        return self.seq[idx],self.nex[idx]
    
    def __len__(self):
        return len(self.seq)
    

dataset = CustomDataset(sequences,next_words)
dataloader = DataLoader(dataset=dataset,
                        batch_size=64,
                        shuffle=True)

# %%
class LSTMPredictor(nn.Module):
    def __init__(self,vocab_size,embedding_dim,hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings=vocab_size,embedding_dim=embedding_dim)
        #batch_first == True means, we have batch:
        self.lstm = nn.LSTM(input_size=embedding_dim,hidden_size=hidden_size,batch_first=True)
        self.fc = nn.Linear(hidden_size,vocab_size)
        
    def forward(self,x):
        embed = self.embedding(x)
        # 3 thing in output in  LSTM cell
        lstm_out, (hidden,_) = self.lstm(embed)
        out = self.fc(torch.squeeze(hidden,dim=0))
        return out 
    
    
    
model = LSTMPredictor(vocab_size=vocab_size,embedding_dim=100,hidden_size=512,)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params=model.parameters(),lr=0.01)

# %%
epochs = 100

for epoch in range(epochs):
    total_loss = 0
    for input,next_word in dataloader:
        input = input.to(device)
        next_word = next_word.to(device)
        
        #forward pass
        out = model(input)
        
        #calculate loss:
        loss = criterion(out,next_word)
        
        #gradient accumulation:
        optimizer.zero_grad()
        
        #backward pass 
        loss.backward()

        #update parameters
        optimizer.step()
        
        total_loss += loss.item()
    print(f"epoch: {epoch+1}  loss: {total_loss/len(dataloader)}")
# Out:
# epoch: 1  loss: 6.978648394395497
# epoch: 2  loss: 5.765236138115244
# epoch: 3  loss: 5.0092354489752084
# epoch: 4  loss: 4.523339759909417
# epoch: 5  loss: 4.239705114916337
# epoch: 6  loss: 4.040840596009877
# epoch: 7  loss: 3.906153757316022
# epoch: 8  loss: 3.7680225946686483
# epoch: 9  loss: 3.7435067569913945
# epoch: 10  loss: 3.6574533943302376
# epoch: 11  loss: 3.5916731643282676
# epoch: 12  loss: 3.554366029097029
# epoch: 13  loss: 3.4907490757871265
# epoch: 14  loss: 3.4911798268310297
# epoch: 15  loss: 3.4474185222436575
# epoch: 16  loss: 3.4102500864296905
# epoch: 17  loss: 3.4142742219542668
# epoch: 18  loss: 3.392621754713295
# epoch: 19  loss: 3.2869059917847974
# epoch: 20  loss: 3.2627398922423687
# epoch: 21  loss: 3.255113498583313
# epoch: 22  loss: 3.23644737320498
# epoch: 23  loss: 3.1968118767600413
# epoch: 24  loss: 3.165904168649153
# epoch: 25  loss: 3.1233082635343568
# epoch: 26  loss: 3.108785924931203
# epoch: 27  loss: 3.0763588140326097
# epoch: 28  loss: 3.063997413747567
# epoch: 29  loss: 3.052501466648638
# epoch: 30  loss: 3.021221227438982
# epoch: 31  loss: 3.011924034800411
# epoch: 32  loss: 2.987420958132783
# epoch: 33  loss: 2.9692301934415646
# epoch: 34  loss: 2.9403839083742502
# epoch: 35  loss: 2.9129326151422235
# epoch: 36  loss: 2.8989439603218363
# epoch: 37  loss: 2.9168950272000527
# epoch: 38  loss: 2.8855016178336026
# epoch: 39  loss: 2.8781400043609713
# epoch: 40  loss: 2.8725220168425034
# epoch: 41  loss: 2.8766400000280585
# epoch: 42  loss: 2.8500539287555315
# epoch: 43  loss: 2.849190130509621
# epoch: 44  loss: 2.8526342183597815
# epoch: 45  loss: 2.844398647004908
# epoch: 46  loss: 2.8211549597338212
# epoch: 47  loss: 2.835602340274606
# epoch: 48  loss: 2.8234987710133073
# epoch: 49  loss: 2.805563994133768
# epoch: 50  loss: 2.7800837841408312
# epoch: 51  loss: 2.7744233852575633
# epoch: 52  loss: 2.775289120506649
# epoch: 53  loss: 2.7964554154183254
# epoch: 54  loss: 2.757375170130375
# epoch: 55  loss: 2.761066356572238
# epoch: 56  loss: 2.7295796474642007
# epoch: 57  loss: 2.728551745562514
# epoch: 58  loss: 2.719562183677658
# epoch: 59  loss: 2.7094475773740405
# epoch: 60  loss: 2.692729062334565
# epoch: 61  loss: 2.694947311405308
# epoch: 62  loss: 2.680555182990949
# epoch: 63  loss: 2.6874325940924244
# epoch: 64  loss: 2.6592690821521536
# epoch: 65  loss: 2.6738804121155386
# epoch: 66  loss: 2.6791936647300876
# epoch: 67  loss: 2.669902529992348
# epoch: 68  loss: 2.667574775662304
# epoch: 69  loss: 2.6572108683507305
# epoch: 70  loss: 2.665001646152213
# epoch: 71  loss: 2.6567124582519215
# epoch: 72  loss: 2.6439314756019057
# epoch: 73  loss: 2.6505294396857586
# epoch: 74  loss: 2.682765125686472
# epoch: 75  loss: 2.6556070681938455
# epoch: 76  loss: 2.6326117077149633
# epoch: 77  loss: 2.604981163562822
# epoch: 78  loss: 2.600163034910013
# epoch: 79  loss: 2.6095919295037087
# epoch: 80  loss: 2.62114485482539
# epoch: 81  loss: 2.5986532753656717
# epoch: 82  loss: 2.597879308412883
# epoch: 83  loss: 2.589595518328927
# epoch: 84  loss: 2.584148416489609
# epoch: 85  loss: 2.593140898706499
# epoch: 86  loss: 2.5795403257874416
# epoch: 87  loss: 2.5924522401380146
# epoch: 88  loss: 2.6058719750770853
# epoch: 89  loss: 2.576458503736937
# epoch: 90  loss: 2.5697382016122834
# epoch: 91  loss: 2.558450853332015
# epoch: 92  loss: 2.5715203395067165

# %%
def prediction(model,sentences,seq_length,word_to_idx,idx_to_word):
    model.eval()
    with torch.no_grad():
        token = sentences.lower().split()
        generated = token.copy()
        
        for _ in range(seq_length):
            # 1. seq_length
            if len(token)>=seq_length:
                current_tokens = generated[-seq_length:]
            else:
                current_tokens = generated 
                
            # 2. get unk,pad idx
            unk_idx = word_to_idx["UNK"]
            pad_idx = word_to_idx["PAD"]
    
            # 3. get idx value
            indices = [word_to_idx.get(tok,unk_idx) for tok in current_tokens]
    
            # 4. fit with seq_length
            if len(indices)<seq_length:
                indices += [pad_idx]*(seq_length-len(indices)) 
    
            # 5. convert into tensor:
            input_tensor = torch.tensor([indices], dtype=torch.long).to(device)
            output = model(input_tensor)
            probabilities = torch.softmax(output, dim=1)
            predicted_idx = torch.argmax(probabilities,dim=1).item()
            predicted_words = idx_to_word.get(predicted_idx,"<UNKNOWN>")
            generated.append(predicted_words)
        return " ".join(generated)

test_sentences = [
    "to sherlock holmes she is always",
    "i have never seen",
    "the quick brown fox",
    "my dear watson",
    "it was a dark and"]

for sentence in test_sentences:
    result = prediction(model,sentence,seq_length,word_to_idx,idx_to_word)
    print(f"sentence: {sentence}  prediction: {result}")
    print()
